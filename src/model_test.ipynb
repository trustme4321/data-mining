# %%
# %load_ext autoreload
# %autoreload 2

import os

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID" 
os.environ['CUDA_VISIBLE_DEVICES'] = '6'
import torch
import pandas as pd
from collections import defaultdict
from torch_geometric.data import InMemoryDataset, Data

import torch.nn.functional as F
import torch.nn as nn
from torch_geometric.nn import GATConv
from torch.optim.lr_scheduler import StepLR
from tqdm import tqdm
from torch_geometric.loader import DataLoader

# %%
import os
from torch_geometric.data import Dataset

class CustomDataset(Dataset):
    def __init__(self, root, node_embeddings, orders, order2nodes, order2labels=None, transform=None, pre_transform=None):
        self.root = root
        self.node_embeddings = node_embeddings
        self.orders = orders
        self.order2nodes = order2nodes
        self.order2labels = order2labels
        
        if not os.path.exists(self.processed_paths[0]):
            self.process()

        super(CustomDataset, self).__init__(root, transform, pre_transform)
        #print('self.raw_paths:', self.raw_paths)
        #print('self.processed_paths:', self.processed_paths)
        
        self.data_list = torch.load(self.processed_paths[0])
    
    
    @property
    def raw_file_names(self): # If raw data is not in the root directory, then call the download function.
        return []
    
    @property
    def processed_file_names(self): # If preprocessed data is not in the root directory, then call the process function.
        return ['task1_graphs.pt']
    
    def download(self):
        pass
    
    def process(self):
        data_list = []
        for order in self.orders:
            edges = []
            for i, node1 in enumerate(self.order2nodes[order]):
                for j, node2 in enumerate(self.order2nodes[order]):
                    if node1 != node2:
                        edges.append([i, j])
            
            #print('order:', order)
            #print('self.order2nodes[order]:', self.order2nodes[order])
            x = self.node_embeddings[self.order2nodes[order]]
            print('self.order2nodes[order]:', self.order2nodes[order])
            print('x:', x)
            edge_index = torch.tensor(edges, dtype=torch.long).t().contiguous()
            y = self.order2labels[order]
            
            data = Data(x=x, edge_index=edge_index, y=y)
            data_list.append(data)
        
        #data, slices = self.collate(data_list)
        torch.save(data_list, self.processed_paths[0])
        
    def len(self):
        return len(self.data_list)
    
    def get(self, idx):
        return self.data_list[idx]

# %%
idx = [1, 2, 3]

a = torch.tensor([0, 1, 2, 3, 4, 5])

print(a[idx])
# Out:
# tensor([1, 2, 3])

# %% [markdown]
# # ToyData

# %%
embeddings = torch.arange(5).reshape(5,1)
order2labels = {0: 0, 1:1, 2:1}
order2nodes = {0: [0, 1], 1: [0, 2, 3], 2: [1, 2, 4]}

# %%
train_ds = CustomDataset(root='../data', node_embeddings=embeddings, order2labels=order2labels, order2nodes=order2nodes)
# Out:
# Data(x=[2, 1], edge_index=[2, 2], y=0)

# %%
print(train_ds[0].edge_index)
# Out:
# tensor([[0, 1],
#         [1, 0]])

# %%
print(train_ds[1].edge_index)
# Out:
# tensor([[0, 0, 1, 1, 2, 2],
#         [1, 2, 0, 2, 0, 1]])

# %%
print(train_ds[2].edge_index)
# Out:
# tensor([[0, 0, 1, 1, 2, 2],
#         [1, 2, 0, 2, 0, 1]])

# %%
train_dl = DataLoader(train_ds, batch_size=2, shuffle=False)

# %%
for data in train_dl:
    print(data)
# Out:
# DataBatch(x=[5, 1], edge_index=[2, 8], y=[2], batch=[5], ptr=[3])
# DataBatch(x=[3, 1], edge_index=[2, 6], y=[1], batch=[3], ptr=[2])

# %%
data1 = next(iter(train_dl))

print(data1)
# Out:
# DataBatch(x=[5, 1], edge_index=[2, 8], y=[2], batch=[5], ptr=[3])

# %%
print(data1.x)
print(data1.edge_index)
print(data1.y)
print(data1.batch)
# Out:
# tensor([[0],
#         [2],
#         [0],
#         [2],
#         [3]])
# tensor([[0, 1, 2, 2, 3, 3, 4, 4],
#         [1, 0, 3, 4, 2, 4, 2, 3]])
# tensor([0, 1])
# tensor([0, 0, 1, 1, 1])

# %% [markdown]
# # Test Custom dataset with real data

# %%
NUM_CUSTOMER =342039
NUM_PRODUCT = 58415

# GAT 모델 정의
class FirstGAT(torch.nn.Module):
    def __init__(self, in_channels, out_channels, heads=1, dropout=0.6):
        super(FirstGAT, self).__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.customer_embedding = nn.Embedding(NUM_CUSTOMER, in_channels) # 342039
        self.product_embedding = nn.Embedding(NUM_PRODUCT, in_channels - 2) # 58415
        self.gat1 = GATConv(in_channels, 8, heads=heads, dropout=dropout)
        self.gat3 = GATConv(8*heads, out_channels, heads=1, concat=False, dropout=dropout)
        #self.gat_test = GATConv(in_channels, out_channels, heads=1, concat=False, dropout=dropout)
    
    def forward(self, prod_features, edge_index):
        
        customer_embeddings = self.customer_embedding(torch.arange(NUM_CUSTOMER).to(device))
        product_embeddings = self.product_embedding(torch.arange(NUM_PRODUCT).to(device))
        prod_features = torch.hstack([product_embeddings, prod_features])
        x = torch.vstack([customer_embeddings, prod_features])
        #print('shape:', x.shape)
        
        x = F.dropout(x, p=0.1, training=self.training)
        x = F.elu(self.gat1(x, edge_index))
        x = F.dropout(x, p=0.1, training=self.training)
        x = F.elu(self.gat3(x, edge_index))
        
        return x

# %%
saved_data = torch.load("/home/myeongjin/data-mining/src/training_data_save")

# %%
def save_model(path, first_model, second_model, opt, scheduler, loss, epoch, **kwargs):
    # kwargs 는 GAT 네트워크 파라미터 in_channels, out_channels, ...

    save_obj = {
            'GAT_params' : kwargs,
            'first_weights': first_model.state_dict(),
            'second_weights': second_model.state_dict(),
            'opt_state': opt.state_dict(),
            'scheduler_state': (scheduler.state_dict() if scheduler else None),
            'loss': loss,
            'epoch': epoch
        }

    #path = os.path.join(path, 'epo_'+str(epoch)+'loss_'+f"{loss:0.3f}")
    path = os.path.join(path, 'epo_'+str(epoch))
    torch.save(save_obj, path)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('device:', device)

# 모델 생성
model1 = FirstGAT(10, 10, heads=4).to(device)
model1.train()

# data
saved_data = saved_data.to(device)
prod_features, edge_index, order2labels, order2nodes = saved_data.prod_features, saved_data.edge_index, saved_data.order2labels, saved_data.order2nodes 

node_features = model1(prod_features, edge_index)
# Out:
# device: cuda
# shape: torch.Size([400454, 10])

# %%
print(node_features.shape)
# Out:
# torch.Size([400454, 10])

# %%
ts = torch.arange(2).reshape(2, 1).to('cuda')

print(ts)
# Out:
# tensor([[0],
#         [1]], device='cuda:0')

# %%
#test_idx = torch.tensor([0, 1, 2])
test_idx = [0, 1, 2]

print(prod_features[test_idx])
# Out:
# tensor([[-0.9907,  0.6129],
#         [ 0.0085, -0.0548],
#         [-1.3010,  1.8149]], device='cuda:0')

# %%
training_orders = list(order2labels.keys())

# %%
nodes = torch.arange(NUM_CUSTOMER + NUM_PRODUCT).reshape(-1, 1)

# %%
print(nodes.shape)
# Out:
# torch.Size([400454, 1])

# %%
NUM_CUSTOMER
# Out:
# 342039

# %%
print(order2nodes[326624])
# Out:
# [192219, 344111, 384742]

# %%
train_ds = CustomDataset(root='../data', node_embeddings=nodes, orders=training_orders, order2labels=order2labels, order2nodes=order2nodes)
# Out:
# self.order2nodes[order]: [192219, 396693, 399166]
# x: tensor([[192219],
#         [396693],
#         [399166]])
# self.order2nodes[order]: [322757, 365716, 397032]
# x: tensor([[322757],
#         [365716],
#         [397032]])
# self.order2nodes[order]: [305375, 396008]
# x: tensor([[305375],
#         [396008]])
# self.order2nodes[order]: [210167, 383726, 355357, 368235]
# x: tensor([[210167],
#         [383726],
#         [355357],
#         [368235]])
# self.order2nodes[order]: [66642, 356867, 364570]
# x: tensor([[ 66642],
#         [356867],
#         [364570]])
# self.order2nodes[order]: [67175, 383092, 365552, 370900]
# x: tensor([[ 67175],
#         [383092],
#         [365552],
#         [370900]])
# self.order2nodes[order]: [78729, 375885]
# x: tensor([[ 78729],
#         [375885]])
# self.order2nodes[order]: [225568, 387187, 357437, 381745, 381520, 360266, 397022]
# x: tensor([[225568],
#         [387187],
#         [357437],
#         [381745],
#         [381520],
#         [360266],
#         [397022]])
# self.order2nodes[order]: [293442, 370692, 364521, 350869, 382916]
# x: tensor([[293442],
#         [370692],
#         [364521],
#         [350869],
#         [382916]])
# self.order2nodes[order]: [321750, 371588, 376881, 368706, 369286, 348602, 392641]
# x: tensor([[321750],
#         [371588],
#         [376881],
#         [368706],
#         [369286],
#         [348602],
#         [392641]])
# self.order2nodes[order]: [341487, 368775, 372962, 367682]
# x: tensor([[341487],
#         [368775],
#         [372962],
#         [367682]])
# self.order2nodes[order]: [287801, 383602]
# x: tensor([[287801],
#         [383602]])
# self.order2nodes[order]: [146815, 347243]
# x: tensor([[146815],
#         [347243]])
# self.order2nodes[order]: [185191, 367779, 383691, 364594]
# x: tensor([[185191],
#         [367779],
#         [383691],
#         [364594]])
# self.order2nodes[order]: [54579, 398835]
# x: tensor([[ 54579],
#         [398835]])
# self.order2nodes[order]: [163416, 349714]
# x: tensor([[163416],
#         [349714]])
# self.order2nodes[order]: [291020, 357560]
# x: tensor([[291020],
#         [357560]])
# self.order2nodes[order]: [79613, 397634, 379230, 363992, 343986, 374445, 354842, 382066, 343649, 396335]
# x: tensor([[ 79613],
#         [397634],
#         [379230],
#         [363992],
#         [343986],
#         [374445],
#         [354842],
#         [382066],
#         [343649],
#         [396335]])
# self.order2nodes[order]: [158293, 400320, 394916]
# x: tensor([[158293],
#         [400320],
#         [394916]])
# self.order2nodes[order]: [156424, 392092]
# x: tensor([[156424],
#         [392092]])
# self.order2nodes[order]: [130442, 359454, 386960, 398789]
# x: tensor([[130442],
#         [359454],
#         [386960],
#         [398789]])
# self.order2nodes[order]: [221992, 374787, 356146, 393015, 352235, 378866]
# x: tensor([[221992],
#         [374787],
#         [356146],
#         [393015],
#         [352235],
#         [378866]])
# self.order2nodes[order]: [115936, 367425]
# x: tensor([[115936],
#         [367425]])
# self.order2nodes[order]: [181536, 370626, 392238, 349271, 383238, 386551, 351902, 352357]
# x: tensor([[181536],
#         [370626],
#         [392238],
#         [349271],
#         [383238],
#         [386551],
#         [351902],
#         [352357]])
# self.order2nodes[order]: [74972, 356891]
# x: tensor([[ 74972],
#         [356891]])
# self.order2nodes[order]: [109276, 378126, 362610]
# x: tensor([[109276],
#         [378126],
#         [362610]])
# self.order2nodes[order]: [66239, 355812, 373664]
# x: tensor([[ 66239],
#         [355812],
#         [373664]])
# self.order2nodes[order]: [251903, 356291]
# x: tensor([[251903],
#         [356291]])
# self.order2nodes[order]: [159533, 352693, 378548]
# x: tensor([[159533],
#         [352693],
#         [378548]])
# self.order2nodes[order]: [248756, 357924]
# x: tensor([[248756],
#         [357924]])
# self.order2nodes[order]: [96168, 357118, 391595, 357323]
# x: tensor([[ 96168],
#         [357118],
#         [391595],
#         [357323]])
# self.order2nodes[order]: [247788, 388078, 343299]
# x: tensor([[247788],
#         [388078],
#         [343299]])
# self.order2nodes[order]: [181807, 362506]
# x: tensor([[181807],
#         [362506]])
# self.order2nodes[order]: [112628, 350144, 385789, 392532, 382897, 389203, 377048, 379221]
# x: tensor([[112628],
#         [350144],
#         [385789],
#         [392532],
#         [382897],
#         [389203],
#         [377048],
#         [379221]])
# self.order2nodes[order]: [326103, 347713]
# x: tensor([[326103],
#         [347713]])
# self.order2nodes[order]: [222814, 376507, 372857, 386721]
# x: tensor([[222814],
#         [376507],
#         [372857],
#         [386721]])
# self.order2nodes[order]: [147516, 377056, 355492]
# x: tensor([[147516],
#         [377056],
#         [355492]])
# self.order2nodes[order]: [172402, 374527]
# x: tensor([[172402],
#         [374527]])
# self.order2nodes[order]: [117610, 385212, 396209]
# x: tensor([[117610],
#         [385212],
#         [396209]])
# self.order2nodes[order]: [250551, 385057, 355779, 395911, 352260]
# x: tensor([[250551],
#         [385057],
#         [355779],
#         [395911],
#         [352260]])
# self.order2nodes[order]: [311619, 355730, 400140, 374361]
# x: tensor([[311619],
#         [355730],
#         [400140],
#         [374361]])
# self.order2nodes[order]: [85932, 388377, 358388]
# x: tensor([[ 85932],
#         [388377],
#         [358388]])
# self.order2nodes[order]: [20852, 376640, 384942]
# x: tensor([[ 20852],
#         [376640],
#         [384942]])
# self.order2nodes[order]: [75553, 344626, 389102]
# x: tensor([[ 75553],
#         [344626],
#         [389102]])
# self.order2nodes[order]: [229056, 395059, 382824, 352054]
# x: tensor([[229056],
#         [395059],
#         [382824],
#         [352054]])
# self.order2nodes[order]: [181610, 372155, 393512]
# x: tensor([[181610],
#         [372155],
#         [393512]])
# self.order2nodes[order]: [266585, 392598]
# x: tensor([[266585],
#         [392598]])
# self.order2nodes[order]: [336492, 379853, 342117, 378866]
# x: tensor([[336492],
#         [379853],
#         [342117],
#         [378866]])
# self.order2nodes[order]: [266646, 360582, 349091, 355788]
# x: tensor([[266646],
#         [360582],
#         [349091],
#         [355788]])
# self.order2nodes[order]: [337755, 384346, 366078]
# x: tensor([[337755],
#         [384346],
#         [366078]])
# self.order2nodes[order]: [44936, 380300, 353786, 391830]
# x: tensor([[ 44936],
#         [380300],
#         [353786],
#         [391830]])
# self.order2nodes[order]: [50267, 365933, 390020, 374658, 351268, 371199]
# x: tensor([[ 50267],
#         [365933],
#         [390020],
#         [374658],
#         [351268],
#         [371199]])
# self.order2nodes[order]: [241832, 354599]
# x: tensor([[241832],
#         [354599]])
# self.order2nodes[order]: [220138, 365322]
# x: tensor([[220138],
#         [365322]])
# self.order2nodes[order]: [168375, 378096, 357192, 354779, 342963, 394270]
# x: tensor([[168375],
#         [378096],
#         [357192],
#         [354779],
#         [342963],
#         [394270]])
# self.order2nodes[order]: [224186, 375198]
# x: tensor([[224186],
#         [375198]])
# self.order2nodes[order]: [182967, 366384, 391168, 345924, 389079, 391643, 352600, 344401, 383660]
# x: tensor([[182967],
#         [366384],
#         [391168],
#         [345924],
#         [389079],
#         [391643],
#         [352600],
#         [344401],
#         [383660]])
# self.order2nodes[order]: [248190, 347109, 390705]
# x: tensor([[248190],
#         [347109],
#         [390705]])
# self.order2nodes[order]: [254901, 379027, 352979, 356536, 359651]
# x: tensor([[254901],
#         [379027],
#         [352979],
#         [356536],
#         [359651]])
# self.order2nodes[order]: [303982, 370809, 360223]
# x: tensor([[303982],
#         [370809],
#         [360223]])
# self.order2nodes[order]: [230351, 367645, 347870, 397207, 361986, 358962, 392520, 394267, 386721, 342991, 355374, 359222]
# x: tensor([[230351],
#         [367645],
#         [347870],
#         [397207],
#         [361986],
#         [358962],
#         [392520],
#         [394267],
#         [386721],
#         [342991],
#         [355374],
#         [359222]])
# self.order2nodes[order]: [36110, 378861, 351010]
# x: tensor([[ 36110],
#         [378861],
#         [351010]])
# self.order2nodes[order]: [164221, 376302, 396248]
# x: tensor([[164221],
#         [376302],
#         [396248]])
# self.order2nodes[order]: [24007, 361801, 394881, 397670, 384265, 397954, 375339, 365773]
# x: tensor([[ 24007],
#         [361801],
#         [394881],
#         [397670],
#         [384265],
#         [397954],
#         [375339],
#         [365773]])
# self.order2nodes[order]: [6053, 371287, 371585, 399971]
# x: tensor([[  6053],
#         [371287],
#         [371585],
#         [399971]])
# self.order2nodes[order]: [219194, 358771, 350782]
# x: tensor([[219194],
#         [358771],
#         [350782]])
# self.order2nodes[order]: [5853, 392390, 395111, 343787]
# x: tensor([[  5853],
#         [392390],
#         [395111],
#         [343787]])
# self.order2nodes[order]: [236034, 354647, 353405]
# x: tensor([[236034],
#         [354647],
#         [353405]])
# self.order2nodes[order]: [19759, 385560, 359222]
# x: tensor([[ 19759],
#         [385560],
#         [359222]])
# self.order2nodes[order]: [4796, 389317, 365271]
# x: tensor([[  4796],
#         [389317],
#         [365271]])
# self.order2nodes[order]: [321524, 361034, 349777, 342223, 371087, 367555, 393828, 375869]
# x: tensor([[321524],
#         [361034],
#         [349777],
#         [342223],
#         [371087],
#         [367555],
#         [393828],
#         [375869]])
# self.order2nodes[order]: [21827, 386397]
# x: tensor([[ 21827],
#         [386397]])
# self.order2nodes[order]: [269943, 393364, 387706]
# x: tensor([[269943],
#         [393364],
#         [387706]])
# self.order2nodes[order]: [322429, 388863, 385835, 364394, 360395]
# x: tensor([[322429],
#         [388863],
#         [385835],
#         [364394],
#         [360395]])
# self.order2nodes[order]: [202294, 354174]
# x: tensor([[202294],
#         [354174]])
# self.order2nodes[order]: [310660, 389598]
# x: tensor([[310660],
#         [389598]])
# self.order2nodes[order]: [57002, 363603]
# x: tensor([[ 57002],
#         [363603]])
# self.order2nodes[order]: [168337, 393958, 352235, 378866, 352827]
# x: tensor([[168337],
#         [393958],
#         [352235],
#         [378866],
#         [352827]])
# self.order2nodes[order]: [275933, 384063]
# x: tensor([[275933],
#         [384063]])
# self.order2nodes[order]: [285143, 390020, 351268, 347260, 398260, 359425, 347837]
# x: tensor([[285143],
#         [390020],
#         [351268],
#         [347260],
#         [398260],
#         [359425],
#         [347837]])
# self.order2nodes[order]: [277977, 378003, 361745]
# x: tensor([[277977],
#         [378003],
#         [361745]])
# self.order2nodes[order]: [304128, 359454, 363301, 397380, 390331]
# x: tensor([[304128],
#         [359454],
#         [363301],
#         [397380],
#         [390331]])
# self.order2nodes[order]: [178310, 344012, 346960, 346512, 357024, 373600, 369829, 371087, 376720, 360780]
# x: tensor([[178310],
#         [344012],
#         [346960],
#         [346512],
#         [357024],
#         [373600],
#         [369829],
#         [371087],
#         [376720],
#         [360780]])
# self.order2nodes[order]: [98960, 382191, 389781, 393942, 380046, 386808]
# x: tensor([[ 98960],
#         [382191],
#         [389781],
#         [393942],
#         [380046],
#         [386808]])
# self.order2nodes[order]: [157321, 374040, 359432, 365284]
# x: tensor([[157321],
#         [374040],
#         [359432],
#         [365284]])
# self.order2nodes[order]: [224248, 395090, 370828, 395480, 368270, 383659, 390870, 365724, 352761]
# x: tensor([[224248],
#         [395090],
#         [370828],
#         [395480],
#         [368270],
#         [383659],
#         [390870],
#         [365724],
#         [352761]])
# self.order2nodes[order]: [96452, 389177, 373280, 380300, 348596, 360386]
# x: tensor([[ 96452],
#         [389177],
#         [373280],
#         [380300],
#         [348596],
#         [360386]])
# self.order2nodes[order]: [246698, 367303, 348997]
# x: tensor([[246698],
#         [367303],
#         [348997]])
# self.order2nodes[order]: [216469, 368552]
# x: tensor([[216469],
#         [368552]])
# self.order2nodes[order]: [298393, 342684, 353865, 360742, 395405, 372857, 379562, 353051]
# x: tensor([[298393],
#         [342684],
#         [353865],
#         [360742],
#         [395405],
#         [372857],
#         [379562],
#         [353051]])
# self.order2nodes[order]: [288678, 349279, 371199, 360352]
# x: tensor([[288678],
#         [349279],
#         [371199],
#         [360352]])
# self.order2nodes[order]: [167966, 370692, 392370, 378444, 379917]
# x: tensor([[167966],
#         [370692],
#         [392370],
#         [378444],
#         [379917]])
# self.order2nodes[order]: [308562, 368370, 398031, 381457, 382623]
# x: tensor([[308562],
#         [368370],
#         [398031],
#         [381457],
#         [382623]])
# self.order2nodes[order]: [296950, 359454]
# x: tensor([[296950],
#         [359454]])
# self.order2nodes[order]: [267457, 364497, 398746, 351726, 396471]
# x: tensor([[267457],
#         [364497],
#         [398746],
#         [351726],
#         [396471]])
# self.order2nodes[order]: [142618, 386063, 386029, 368485]
# x: tensor([[142618],
#         [386063],
#         [386029],
#         [368485]])
# self.order2nodes[order]: [212709, 354742, 378764, 354235, 391456, 359595, 350437]
# x: tensor([[212709],
#         [354742],
#         [378764],
#         [354235],
#         [391456],
#         [359595],
#         [350437]])
# self.order2nodes[order]: [22297, 358746, 392240, 348212, 383806]
# x: tensor([[ 22297],
#         [358746],
#         [392240],
#         [348212],
#         [383806]])
# self.order2nodes[order]: [165664, 396511, 346156]
# x: tensor([[165664],
#         [396511],
#         [346156]])
# self.order2nodes[order]: [175377, 368525]
# x: tensor([[175377],
#         [368525]])
# self.order2nodes[order]: [43504, 373790]
# x: tensor([[ 43504],
#         [373790]])
# self.order2nodes[order]: [73517, 386948]
# x: tensor([[ 73517],
#         [386948]])
# self.order2nodes[order]: [195038, 361926, 375878, 391757, 349189, 350869, 374726, 347426, 388141]
# x: tensor([[195038],
#         [361926],
#         [375878],
#         [391757],
#         [349189],
#         [350869],
#         [374726],
#         [347426],
#         [388141]])
# self.order2nodes[order]: [315942, 344865, 350138, 370779, 349595, 379558, 350695]
# x: tensor([[315942],
#         [344865],
#         [350138],
#         [370779],
#         [349595],
#         [379558],
#         [350695]])
# self.order2nodes[order]: [273583, 390789, 378967]
# x: tensor([[273583],
#         [390789],
#         [378967]])
# self.order2nodes[order]: [179499, 367352, 359581, 390765, 382967, 361067]
# x: tensor([[179499],
#         [367352],
#         [359581],
#         [390765],
#         [382967],
#         [361067]])
# self.order2nodes[order]: [318944, 348192, 393613, 348596]
# x: tensor([[318944],
#         [348192],
#         [393613],
#         [348596]])
# self.order2nodes[order]: [50253, 379558, 389303]
# x: tensor([[ 50253],
#         [379558],
#         [389303]])
# self.order2nodes[order]: [243043, 347047, 356238]
# x: tensor([[243043],
#         [347047],
#         [356238]])
# self.order2nodes[order]: [12526, 385212]
# x: tensor([[ 12526],
#         [385212]])
# self.order2nodes[order]: [179699, 349373, 390765, 392634, 352109, 379162, 357496, 360684, 387991, 378616]
# x: tensor([[179699],
#         [349373],
#         [390765],
#         [392634],
#         [352109],
#         [379162],
#         [357496],
#         [360684],
#         [387991],
#         [378616]])
# self.order2nodes[order]: [273847, 349941, 354299, 392556]
# x: tensor([[273847],
#         [349941],
#         [354299],
#         [392556]])
# self.order2nodes[order]: [41335, 361993, 366882, 355794, 378630, 346166, 342117, 371713, 399971]
# x: tensor([[ 41335],
#         [361993],
#         [366882],
#         [355794],
#         [378630],
#         [346166],
#         [342117],
#         [371713],
#         [399971]])
# self.order2nodes[order]: [240221, 365422]
# x: tensor([[240221],
#         [365422]])
# self.order2nodes[order]: [66893, 378941, 371470, 347955]
# x: tensor([[ 66893],
#         [378941],
#         [371470],
#         [347955]])
# self.order2nodes[order]: [291591, 347720, 393863]
# x: tensor([[291591],
#         [347720],
#         [393863]])
# self.order2nodes[order]: [97302, 381248]
# x: tensor([[ 97302],
#         [381248]])
# self.order2nodes[order]: [88948, 368848, 348223, 357067]
# x: tensor([[ 88948],
#         [368848],
#         [348223],
#         [357067]])
# self.order2nodes[order]: [278194, 361993, 366264, 383506, 395090, 361989, 349062, 350427]
# x: tensor([[278194],
#         [361993],
#         [366264],
#         [383506],
#         [395090],
#         [361989],
#         [349062],
#         [350427]])
# self.order2nodes[order]: [260672, 388443]
# x: tensor([[260672],
#         [388443]])
# self.order2nodes[order]: [1664, 350928, 358968, 352761, 359499]
# x: tensor([[  1664],
#         [350928],
#         [358968],
#         [352761],
#         [359499]])
# self.order2nodes[order]: [53990, 377830, 356839, 383500, 380730]
# x: tensor([[ 53990],
#         [377830],
#         [356839],
#         [383500],
#         [380730]])
# self.order2nodes[order]: [35472, 389551, 377616]
# x: tensor([[ 35472],
#         [389551],
#         [377616]])
# self.order2nodes[order]: [340468, 342664, 365435]
# x: tensor([[340468],
#         [342664],
#         [365435]])
# self.order2nodes[order]: [34602, 361751, 381191]
# x: tensor([[ 34602],
#         [361751],
#         [381191]])
# self.order2nodes[order]: [108251, 378239, 395635, 371356]
# x: tensor([[108251],
#         [378239],
#         [395635],
#         [371356]])
# self.order2nodes[order]: [241535, 357872, 342979]
# x: tensor([[241535],
#         [357872],
#         [342979]])
# self.order2nodes[order]: [102121, 347837, 375869, 345295]
# x: tensor([[102121],
#         [347837],
#         [375869],
#         [345295]])
# self.order2nodes[order]: [25896, 372251, 376640]
# x: tensor([[ 25896],
#         [372251],
#         [376640]])
# self.order2nodes[order]: [189756, 342527, 389861, 368869, 379917]
# x: tensor([[189756],
#         [342527],
#         [389861],
#         [368869],
#         [379917]])
# self.order2nodes[order]: [101119, 375789, 343696]
# x: tensor([[101119],
#         [375789],
#         [343696]])
# self.order2nodes[order]: [159511, 367423, 363166, 344338, 367123]
# x: tensor([[159511],
#         [367423],
#         [363166],
#         [344338],
#         [367123]])
# self.order2nodes[order]: [1986, 380423, 348183, 349868, 389108, 376199]
# x: tensor([[  1986],
#         [380423],
#         [348183],
#         [349868],
#         [389108],
#         [376199]])
# self.order2nodes[order]: [160612, 360428, 396008]
# x: tensor([[160612],
#         [360428],
#         [396008]])
# self.order2nodes[order]: [258129, 394692, 387612, 362960, 348314]
# x: tensor([[258129],
#         [394692],
#         [387612],
#         [362960],
#         [348314]])
# self.order2nodes[order]: [62245, 369968, 347587, 371470, 397267, 356406, 345295, 383435]
# x: tensor([[ 62245],
#         [369968],
#         [347587],
#         [371470],
#         [397267],
#         [356406],
#         [345295],
#         [383435]])
# self.order2nodes[order]: [140155, 370688, 357846, 362972]
# x: tensor([[140155],
#         [370688],
#         [357846],
#         [362972]])
# self.order2nodes[order]: [152583, 353699, 364598, 391819, 381512, 368776]
# x: tensor([[152583],
#         [353699],
#         [364598],
#         [391819],
#         [381512],
#         [368776]])
# self.order2nodes[order]: [72767, 358194, 388811, 353830, 351074]
# x: tensor([[ 72767],
#         [358194],
#         [388811],
#         [353830],
#         [351074]])
# self.order2nodes[order]: [330989, 393613, 358623, 357055, 393927, 394781]
# x: tensor([[330989],
#         [393613],
#         [358623],
#         [357055],
#         [393927],
#         [394781]])
# self.order2nodes[order]: [243281, 348361]
# x: tensor([[243281],
#         [348361]])
# self.order2nodes[order]: [240940, 349593]
# x: tensor([[240940],
#         [349593]])
# self.order2nodes[order]: [203239, 389425, 389091, 364542]
# x: tensor([[203239],
#         [389425],
#         [389091],
#         [364542]])
# self.order2nodes[order]: [200204, 393527, 389738, 396577, 375869]
# x: tensor([[200204],
#         [393527],
#         [389738],
#         [396577],
#         [375869]])
# self.order2nodes[order]: [76192, 366716, 393379]
# x: tensor([[ 76192],
#         [366716],
#         [393379]])
# self.order2nodes[order]: [83183, 398449, 379702, 344407]
# x: tensor([[ 83183],
#         [398449],
#         [379702],
#         [344407]])
# self.order2nodes[order]: [221269, 360143, 395078, 381248, 387795]
# x: tensor([[221269],
#         [360143],
#         [395078],
#         [381248],
#         [387795]])
# self.order2nodes[order]: [337564, 348778, 345350]
# x: tensor([[337564],
#         [348778],
#         [345350]])
# self.order2nodes[order]: [215921, 378138, 346093]
# x: tensor([[215921],
#         [378138],
#         [346093]])
# self.order2nodes[order]: [283400, 375889, 371201]
# x: tensor([[283400],
#         [375889],
#         [371201]])
# self.order2nodes[order]: [113054, 363842, 351154, 348017, 392630, 381160, 379702, 352299, 388296]
# x: tensor([[113054],
#         [363842],
#         [351154],
#         [348017],
#         [392630],
#         [381160],
#         [379702],
#         [352299],
#         [388296]])
# self.order2nodes[order]: [155743, 343726]
# x: tensor([[155743],
#         [343726]])
# self.order2nodes[order]: [336423, 393158, 374445, 376583, 392330, 360428, 366816, 369597, 392074, 385171, 379791, 356657, 378838, 374726, 385712, 342459, 373997, 387565, 398786]
# x: tensor([[336423],
#         [393158],
#         [374445],
#         [376583],
#         [392330],
#         [360428],
#         [366816],
#         [369597],
#         [392074],
#         [385171],
#         [379791],
#         [356657],
#         [378838],
#         [374726],
#         [385712],
#         [342459],
#         [373997],
#         [387565],
#         [398786]])
# self.order2nodes[order]: [326112, 396470, 384883, 342684, 399591, 391900, 371723, 379129, 374727]
# x: tensor([[326112],
#         [396470],
#         [384883],
#         [342684],
#         [399591],
#         [391900],
#         [371723],
#         [379129],
#         [374727]])
# self.order2nodes[order]: [52741, 345693, 362204]
# x: tensor([[ 52741],
#         [345693],
#         [362204]])
# self.order2nodes[order]: [150353, 361497, 394781, 375869]
# x: tensor([[150353],
#         [361497],
#         [394781],
#         [375869]])
# self.order2nodes[order]: [118269, 393855]
# x: tensor([[118269],
#         [393855]])
# self.order2nodes[order]: [24134, 363889, 350857]
# x: tensor([[ 24134],
#         [363889],
#         [350857]])
# self.order2nodes[order]: [123838, 381611]
# x: tensor([[123838],
#         [381611]])
# self.order2nodes[order]: [114898, 380810]
# x: tensor([[114898],
#         [380810]])
# self.order2nodes[order]: [47867, 382957]
# x: tensor([[ 47867],
#         [382957]])
# self.order2nodes[order]: [285826, 359297, 357247, 351403, 378360, 356839]
# x: tensor([[285826],
#         [359297],
#         [357247],
#         [351403],
#         [378360],
#         [356839]])
# self.order2nodes[order]: [55568, 385270, 389598, 374257, 395348, 390637, 376583, 365271, 398214]
# x: tensor([[ 55568],
#         [385270],
#         [389598],
#         [374257],
#         [395348],
#         [390637],
#         [376583],
#         [365271],
#         [398214]])
# self.order2nodes[order]: [208558, 348834]
# x: tensor([[208558],
#         [348834]])
# self.order2nodes[order]: [78382, 350803]
# x: tensor([[ 78382],
#         [350803]])
# self.order2nodes[order]: [2995, 389499, 357336, 386808]
# x: tensor([[  2995],
#         [389499],
#         [357336],
#         [386808]])
# self.order2nodes[order]: [319758, 394667, 396502]
# x: tensor([[319758],
#         [394667],
#         [396502]])
# self.order2nodes[order]: [230532, 361750]
# x: tensor([[230532],
#         [361750]])
# self.order2nodes[order]: [119163, 372527, 388078, 343299, 390636]
# x: tensor([[119163],
#         [372527],
#         [388078],
#         [343299],
#         [390636]])
# self.order2nodes[order]: [310524, 352399]
# x: tensor([[310524],
#         [352399]])
# self.order2nodes[order]: [62264, 381962, 386632, 361647]
# x: tensor([[ 62264],
#         [381962],
#         [386632],
#         [361647]])
# self.order2nodes[order]: [191223, 373160, 399268, 385214, 391393]
# x: tensor([[191223],
#         [373160],
#         [399268],
#         [385214],
#         [391393]])
# self.order2nodes[order]: [173794, 348117]
# x: tensor([[173794],
#         [348117]])
# self.order2nodes[order]: [258303, 358288, 352827]
# x: tensor([[258303],
#         [358288],
#         [352827]])
# self.order2nodes[order]: [12526, 352490, 372926, 369219]
# x: tensor([[ 12526],
#         [352490],
#         [372926],
#         [369219]])
# self.order2nodes[order]: [341308, 364661, 346130]
# x: tensor([[341308],
#         [364661],
#         [346130]])
# self.order2nodes[order]: [115812, 388352, 366140, 375158, 350004]
# x: tensor([[115812],
#         [388352],
#         [366140],
#         [375158],
#         [350004]])
# self.order2nodes[order]: [29255, 396811, 369853]
# x: tensor([[ 29255],
#         [396811],
#         [369853]])
# self.order2nodes[order]: [196594, 358654, 367435, 398276, 356752, 371434, 380494]
# x: tensor([[196594],
#         [358654],
#         [367435],
#         [398276],
#         [356752],
#         [371434],
#         [380494]])
# self.order2nodes[order]: [131830, 359380]
# x: tensor([[131830],
#         [359380]])
# self.order2nodes[order]: [84611, 357484]
# x: tensor([[ 84611],
#         [357484]])
# self.order2nodes[order]: [47752, 388480, 377127, 363696, 358246, 350782]
# x: tensor([[ 47752],
#         [388480],
#         [377127],
#         [363696],
#         [358246],
#         [350782]])
# self.order2nodes[order]: [121404, 372149, 344457]
# x: tensor([[121404],
#         [372149],
#         [344457]])
# self.order2nodes[order]: [238661, 397902]
# x: tensor([[238661],
#         [397902]])
# self.order2nodes[order]: [255460, 361615]
# x: tensor([[255460],
#         [361615]])
# self.order2nodes[order]: [243699, 367331, 347766, 351427, 370767]
# x: tensor([[243699],
#         [367331],
#         [347766],
#         [351427],
#         [370767]])
# self.order2nodes[order]: [104182, 355586, 393364, 391408]
# x: tensor([[104182],
#         [355586],
#         [393364],
#         [391408]])
# self.order2nodes[order]: [134105, 388538, 392634, 358595, 394079, 344065, 393942, 386808, 373997, 360880, 398312, 365284, 397022, 386721]
# x: tensor([[134105],
#         [388538],
#         [392634],
#         [358595],
#         [394079],
#         [344065],
#         [393942],
#         [386808],
#         [373997],
#         [360880],
#         [398312],
#         [365284],
#         [397022],
#         [386721]])
# self.order2nodes[order]: [160467, 398789, 373014]
# x: tensor([[160467],
#         [398789],
#         [373014]])
# self.order2nodes[order]: [22756, 345317]
# x: tensor([[ 22756],
#         [345317]])
# self.order2nodes[order]: [155258, 378996]
# x: tensor([[155258],
#         [378996]])
# self.order2nodes[order]: [57716, 399257, 352613]
# x: tensor([[ 57716],
#         [399257],
#         [352613]])
# self.order2nodes[order]: [95983, 343155, 374147, 383423]
# x: tensor([[ 95983],
#         [343155],
#         [374147],
#         [383423]])
# self.order2nodes[order]: [85118, 352744, 371588, 348456]
# x: tensor([[ 85118],
#         [352744],
#         [371588],
#         [348456]])
# self.order2nodes[order]: [182727, 393364, 377779]
# x: tensor([[182727],
#         [393364],
#         [377779]])
# self.order2nodes[order]: [109598, 371395]
# x: tensor([[109598],
#         [371395]])
# self.order2nodes[order]: [141808, 382257, 357537, 396335, 345575, 386871, 400108]
# x: tensor([[141808],
#         [382257],
#         [357537],
#         [396335],
#         [345575],
#         [386871],
#         [400108]])
# self.order2nodes[order]: [10947, 342350]
# x: tensor([[ 10947],
#         [342350]])
# self.order2nodes[order]: [204156, 379712, 398526, 361491, 376680, 358993]
# x: tensor([[204156],
#         [379712],
#         [398526],
#         [361491],
#         [376680],
#         [358993]])
# self.order2nodes[order]: [12583, 357055]
# x: tensor([[ 12583],
#         [357055]])
# self.order2nodes[order]: [30789, 392049]
# x: tensor([[ 30789],
#         [392049]])
# self.order2nodes[order]: [157073, 352062, 381822, 360085, 342991, 399971]
# x: tensor([[157073],
#         [352062],
#         [381822],
#         [360085],
#         [342991],
#         [399971]])
# self.order2nodes[order]: [106698, 362539, 368779, 399971]
# x: tensor([[106698],
#         [362539],
#         [368779],
#         [399971]])
# self.order2nodes[order]: [162475, 392130, 355371]
# x: tensor([[162475],
#         [392130],
#         [355371]])
# self.order2nodes[order]: [254037, 346373, 344757, 378129]
# x: tensor([[254037],
#         [346373],
#         [344757],
#         [378129]])
# self.order2nodes[order]: [200076, 368275, 371611, 395317, 366549, 368359, 396301, 379131, 396476, 368248, 389644]
# x: tensor([[200076],
#         [368275],
#         [371611],
#         [395317],
#         [366549],
#         [368359],
#         [396301],
#         [379131],
#         [396476],
#         [368248],
#         [389644]])
# self.order2nodes[order]: [292677, 376874, 348071]
# x: tensor([[292677],
#         [376874],
#         [348071]])
# self.order2nodes[order]: [119656, 383880, 342184, 386459, 358270]
# x: tensor([[119656],
#         [383880],
#         [342184],
#         [386459],
#         [358270]])
# self.order2nodes[order]: [176824, 368621, 378885, 380987, 397186, 370605, 375812, 346130]
# x: tensor([[176824],
#         [368621],
#         [378885],
#         [380987],
#         [397186],
#         [370605],
#         [375812],
#         [346130]])
# self.order2nodes[order]: [197643, 344755, 361676, 367223, 353415, 398855, 350782]
# x: tensor([[197643],
#         [344755],
#         [361676],
#         [367223],
#         [353415],
#         [398855],
#         [350782]])
# self.order2nodes[order]: [150859, 384120, 353805]
# x: tensor([[150859],
#         [384120],
#         [353805]])
# self.order2nodes[order]: [80486, 355304, 355617, 395646, 373945]
# x: tensor([[ 80486],
#         [355304],
#         [355617],
#         [395646],
#         [373945]])
# self.order2nodes[order]: [106675, 367653]
# x: tensor([[106675],
#         [367653]])
# self.order2nodes[order]: [47625, 393364, 398232]
# x: tensor([[ 47625],
#         [393364],
#         [398232]])
# self.order2nodes[order]: [285070, 356887]
# x: tensor([[285070],
#         [356887]])
# self.order2nodes[order]: [318570, 345056, 344416, 392916, 369190, 347225, 368275]
# x: tensor([[318570],
#         [345056],
#         [344416],
#         [392916],
#         [369190],
#         [347225],
#         [368275]])
# self.order2nodes[order]: [108683, 359984]
# x: tensor([[108683],
#         [359984]])
# self.order2nodes[order]: [204711, 395239, 386063]
# x: tensor([[204711],
#         [395239],
#         [386063]])
# self.order2nodes[order]: [101535, 376351, 355582]
# x: tensor([[101535],
#         [376351],
#         [355582]])
# self.order2nodes[order]: [54585, 376881, 344731, 381064]
# x: tensor([[ 54585],
#         [376881],
#         [344731],
#         [381064]])
# self.order2nodes[order]: [99665, 346525, 373169, 342642]
# x: tensor([[ 99665],
#         [346525],
#         [373169],
#         [342642]])
# self.order2nodes[order]: [184788, 379083, 392433, 388296]
# x: tensor([[184788],
#         [379083],
#         [392433],
#         [388296]])
# self.order2nodes[order]: [82799, 369235]
# x: tensor([[ 82799],
#         [369235]])
# self.order2nodes[order]: [212319, 351983, 357964]
# x: tensor([[212319],
#         [351983],
#         [357964]])
# self.order2nodes[order]: [55648, 344083, 356354, 372920, 342284, 361434, 383625, 394781]
# x: tensor([[ 55648],
#         [344083],
#         [356354],
#         [372920],
#         [342284],
#         [361434],
#         [383625],
#         [394781]])
# self.order2nodes[order]: [249910, 370381, 358136, 398260]
# x: tensor([[249910],
#         [370381],
#         [358136],
#         [398260]])
# self.order2nodes[order]: [153402, 347557, 353269, 394483]
# x: tensor([[153402],
#         [347557],
#         [353269],
#         [394483]])
# self.order2nodes[order]: [40290, 370479, 385712, 371688]
# x: tensor([[ 40290],
#         [370479],
#         [385712],
#         [371688]])
# self.order2nodes[order]: [335549, 375723, 396224, 381073, 382982, 391870]
# x: tensor([[335549],
#         [375723],
#         [396224],
#         [381073],
#         [382982],
#         [391870]])
# self.order2nodes[order]: [29323, 352062, 355171, 364328, 351779, 397256]
# x: tensor([[ 29323],
#         [352062],
#         [355171],
#         [364328],
#         [351779],
#         [397256]])
# self.order2nodes[order]: [29704, 373280, 361801, 363290, 395534]
# x: tensor([[ 29704],
#         [373280],
#         [361801],
#         [363290],
#         [395534]])
# self.order2nodes[order]: [134376, 375807]
# x: tensor([[134376],
#         [375807]])
# self.order2nodes[order]: [241447, 345056, 394816, 363409, 393996, 371385]
# x: tensor([[241447],
#         [345056],
#         [394816],
#         [363409],
#         [393996],
#         [371385]])
# self.order2nodes[order]: [304230, 385738, 383142, 365225]
# x: tensor([[304230],
#         [385738],
#         [383142],
#         [365225]])
# self.order2nodes[order]: [138177, 390907, 352673]
# x: tensor([[138177],
#         [390907],
#         [352673]])
# self.order2nodes[order]: [338838, 357615, 377001]
# x: tensor([[338838],
#         [357615],
#         [377001]])
# self.order2nodes[order]: [208260, 392324, 357846]
# x: tensor([[208260],
#         [392324],
#         [357846]])
# self.order2nodes[order]: [229665, 391565, 343620, 353825]
# x: tensor([[229665],
#         [391565],
#         [343620],
#         [353825]])
# self.order2nodes[order]: [261210, 390957, 381645, 372917, 393990]
# x: tensor([[261210],
#         [390957],
#         [381645],
#         [372917],
#         [393990]])
# self.order2nodes[order]: [196767, 378560, 397022]
# x: tensor([[196767],
#         [378560],
#         [397022]])
# self.order2nodes[order]: [138116, 376881, 351154, 364594, 376051, 387724, 369033, 354591]
# x: tensor([[138116],
#         [376881],
#         [351154],
#         [364594],
#         [376051],
#         [387724],
#         [369033],
#         [354591]])
# self.order2nodes[order]: [225926, 357872, 354299]
# x: tensor([[225926],
#         [357872],
#         [354299]])
# self.order2nodes[order]: [239907, 396693, 345010, 390228, 399166, 369181, 379917]
# x: tensor([[239907],
#         [396693],
#         [345010],
#         [390228],
#         [399166],
#         [369181],
#         [379917]])
# self.order2nodes[order]: [330746, 372136]
# x: tensor([[330746],
#         [372136]])
# self.order2nodes[order]: [154757, 362173]
# x: tensor([[154757],
#         [362173]])
# self.order2nodes[order]: [100764, 381979, 346373]
# x: tensor([[100764],
#         [381979],
#         [346373]])
# self.order2nodes[order]: [20588, 352283, 385464]
# x: tensor([[ 20588],
#         [352283],
#         [385464]])
# self.order2nodes[order]: [185156, 383384]
# x: tensor([[185156],
#         [383384]])
# self.order2nodes[order]: [222780, 345616, 394259, 368577, 371470, 368253, 363166, 366573, 352186, 388329, 379643, 342991, 353703, 357846, 358787]
# x: tensor([[222780],
#         [345616],
#         [394259],
#         [368577],
#         [371470],
#         [368253],
#         [363166],
#         [366573],
#         [352186],
#         [388329],
#         [379643],
#         [342991],
#         [353703],
#         [357846],
#         [358787]])
# self.order2nodes[order]: [34684, 356908, 390564, 354087, 346338, 378616, 347444]
# x: tensor([[ 34684],
#         [356908],
#         [390564],
#         [354087],
#         [346338],
#         [378616],
#         [347444]])
# self.order2nodes[order]: [9481, 394916]
# x: tensor([[  9481],
#         [394916]])
# self.order2nodes[order]: [38127, 397662, 349227, 392539, 387565, 360865, 374814]
# x: tensor([[ 38127],
#         [397662],
#         [349227],
#         [392539],
#         [387565],
#         [360865],
#         [374814]])
# self.order2nodes[order]: [270377, 382963, 388360]
# x: tensor([[270377],
#         [382963],
#         [388360]])
# self.order2nodes[order]: [262249, 387573, 377723, 377397]
# x: tensor([[262249],
#         [387573],
#         [377723],
#         [377397]])
# self.order2nodes[order]: [38485, 396987, 350744]
# x: tensor([[ 38485],
#         [396987],
#         [350744]])
# self.order2nodes[order]: [262286, 373963, 375237, 397269, 392704, 355756, 376871]
# x: tensor([[262286],
#         [373963],
#         [375237],
#         [397269],
#         [392704],
#         [355756],
#         [376871]])
# self.order2nodes[order]: [285115, 355171, 369150, 395317, 372210]
# x: tensor([[285115],
#         [355171],
#         [369150],
#         [395317],
#         [372210]])
# self.order2nodes[order]: [274257, 377393, 357343, 359380, 376349, 353943, 356701, 378441, 345891]
# x: tensor([[274257],
#         [377393],
#         [357343],
#         [359380],
#         [376349],
#         [353943],
#         [356701],
#         [378441],
#         [345891]])
# self.order2nodes[order]: [312942, 392725, 361636]
# x: tensor([[312942],
#         [392725],
#         [361636]])
# self.order2nodes[order]: [340205, 342172]
# x: tensor([[340205],
#         [342172]])
# self.order2nodes[order]: [71475, 352677, 357900, 369170, 371672, 355528, 377213]
# x: tensor([[ 71475],
#         [352677],
#         [357900],
#         [369170],
#         [371672],
#         [355528],
#         [377213]])
# self.order2nodes[order]: [79313, 364980, 382505, 350782, 388903]
# x: tensor([[ 79313],
#         [364980],
#         [382505],
#         [350782],
#         [388903]])
# self.order2nodes[order]: [228005, 361751, 363290, 383271]
# x: tensor([[228005],
#         [361751],
#         [363290],
#         [383271]])
# self.order2nodes[order]: [257657, 344727, 345891, 375911, 386808, 358151, 373069, 351972, 388857, 369853]
# x: tensor([[257657],
#         [344727],
#         [345891],
#         [375911],
#         [386808],
#         [358151],
#         [373069],
#         [351972],
#         [388857],
#         [369853]])
# self.order2nodes[order]: [116008, 384702, 342527]
# x: tensor([[116008],
#         [384702],
#         [342527]])
# self.order2nodes[order]: [262163, 395495, 344308, 380263, 394641, 375807]
# x: tensor([[262163],
#         [395495],
#         [344308],
#         [380263],
#         [394641],
#         [375807]])
# self.order2nodes[order]: [256368, 360225]
# x: tensor([[256368],
#         [360225]])
# self.order2nodes[order]: [150109, 369817, 360776, 368198, 393035, 365439, 365271, 371993, 347426, 400330]
# x: tensor([[150109],
#         [369817],
#         [360776],
#         [368198],
#         [393035],
#         [365439],
#         [365271],
#         [371993],
#         [347426],
#         [400330]])
# self.order2nodes[order]: [176804, 352690, 361422]
# x: tensor([[176804],
#         [352690],
#         [361422]])
# self.order2nodes[order]: [40341, 354814, 378569, 389154, 392520, 369389, 357846]
# x: tensor([[ 40341],
#         [354814],
#         [378569],
#         [389154],
#         [392520],
#         [369389],
#         [357846]])
# self.order2nodes[order]: [335472, 376236, 361030]
# x: tensor([[335472],
#         [376236],
#         [361030]])
# self.order2nodes[order]: [148574, 380133, 391852]
# x: tensor([[148574],
#         [380133],
#         [391852]])
# self.order2nodes[order]: [331785, 387776, 358800, 365814]
# x: tensor([[331785],
#         [387776],
#         [358800],
#         [365814]])
# self.order2nodes[order]: [109231, 351779, 367387, 375889]
# x: tensor([[109231],
#         [351779],
#         [367387],
#         [375889]])
# self.order2nodes[order]: [317589, 369319]
# x: tensor([[317589],
#         [369319]])
# self.order2nodes[order]: [181280, 381045]
# x: tensor([[181280],
#         [381045]])
# self.order2nodes[order]: [303373, 350195, 388543, 344683]
# x: tensor([[303373],
#         [350195],
#         [388543],
#         [344683]])
# self.order2nodes[order]: [289099, 380170]
# x: tensor([[289099],
#         [380170]])
# self.order2nodes[order]: [75276, 348359]
# x: tensor([[ 75276],
#         [348359]])
# self.order2nodes[order]: [299591, 377504, 369452, 400171, 378846, 369518]
# x: tensor([[299591],
#         [377504],
#         [369452],
#         [400171],
#         [378846],
#         [369518]])
# self.order2nodes[order]: [206122, 348361]
# x: tensor([[206122],
#         [348361]])
# self.order2nodes[order]: [292815, 381660, 360109, 345918, 390456, 360054, 393925, 351131, 381982, 362302]
# x: tensor([[292815],
#         [381660],
#         [360109],
#         [345918],
#         [390456],
#         [360054],
#         [393925],
#         [351131],
#         [381982],
#         [362302]])
# self.order2nodes[order]: [288907, 378225, 355357, 367370, 386274, 371963]
# x: tensor([[288907],
#         [378225],
#         [355357],
#         [367370],
#         [386274],
#         [371963]])
# self.order2nodes[order]: [248227, 368742, 360743]
# x: tensor([[248227],
#         [368742],
#         [360743]])
# self.order2nodes[order]: [30943, 386243, 381484]
# x: tensor([[ 30943],
#         [386243],
#         [381484]])
# self.order2nodes[order]: [116908, 342512, 394799, 382916, 358418]
# x: tensor([[116908],
#         [342512],
#         [394799],
#         [382916],
#         [358418]])
# self.order2nodes[order]: [303811, 384229]
# x: tensor([[303811],
#         [384229]])
# self.order2nodes[order]: [42130, 345317, 371299, 362791, 397286, 354814, 372982, 388885, 347786, 361986, 360494]
# x: tensor([[ 42130],
#         [345317],
#         [371299],
#         [362791],
#         [397286],
#         [354814],
#         [372982],
#         [388885],
#         [347786],
#         [361986],
#         [360494]])
# self.order2nodes[order]: [198398, 348071, 348495, 366993, 367097, 365707, 363696, 356170]
# x: tensor([[198398],
#         [348071],
#         [348495],
#         [366993],
#         [367097],
#         [365707],
#         [363696],
#         [356170]])
# self.order2nodes[order]: [102010, 365250]
# x: tensor([[102010],
#         [365250]])
# self.order2nodes[order]: [177857, 364219, 382643, 343365, 352964]
# x: tensor([[177857],
#         [364219],
#         [382643],
#         [343365],
#         [352964]])
# self.order2nodes[order]: [146929, 392916, 393958, 381825, 357964, 357846]
# x: tensor([[146929],
#         [392916],
#         [393958],
#         [381825],
#         [357964],
#         [357846]])
# self.order2nodes[order]: [237169, 384347, 368702, 363701]
# x: tensor([[237169],
#         [384347],
#         [368702],
#         [363701]])
# self.order2nodes[order]: [296439, 391565, 383680]
# x: tensor([[296439],
#         [391565],
#         [383680]])
# self.order2nodes[order]: [6994, 364376]
# x: tensor([[  6994],
#         [364376]])
# self.order2nodes[order]: [77084, 373440, 360161, 355462]
# x: tensor([[ 77084],
#         [373440],
#         [360161],
#         [355462]])
# self.order2nodes[order]: [319791, 387375, 374197]
# x: tensor([[319791],
#         [387375],
#         [374197]])
# self.order2nodes[order]: [145361, 361829, 342285]
# x: tensor([[145361],
#         [361829],
#         [342285]])
# self.order2nodes[order]: [264075, 398666, 362198]
# x: tensor([[264075],
#         [398666],
#         [362198]])
# self.order2nodes[order]: [38400, 344072, 367068]
# x: tensor([[ 38400],
#         [344072],
#         [367068]])
# self.order2nodes[order]: [85017, 372374, 351154, 396693, 379419, 349117, 371993, 384991, 361259]
# x: tensor([[ 85017],
#         [372374],
#         [351154],
#         [396693],
#         [379419],
#         [349117],
#         [371993],
#         [384991],
#         [361259]])
# self.order2nodes[order]: [325824, 350842, 388321, 378866, 359222, 347784]
# x: tensor([[325824],
#         [350842],
#         [388321],
#         [378866],
#         [359222],
#         [347784]])
# self.order2nodes[order]: [172009, 380897]
# x: tensor([[172009],
#         [380897]])
# self.order2nodes[order]: [30399, 354101, 345900, 365747]
# x: tensor([[ 30399],
#         [354101],
#         [345900],
#         [365747]])
# self.order2nodes[order]: [35348, 369219, 367034]
# x: tensor([[ 35348],
#         [369219],
#         [367034]])
# self.order2nodes[order]: [280304, 355080, 373650, 397069, 343257]
# x: tensor([[280304],
#         [355080],
#         [373650],
#         [397069],
#         [343257]])
# self.order2nodes[order]: [277155, 362012]
# x: tensor([[277155],
#         [362012]])
# self.order2nodes[order]: [128537, 386960, 394562, 397069]
# x: tensor([[128537],
#         [386960],
#         [394562],
#         [397069]])
# self.order2nodes[order]: [202555, 375497]
# x: tensor([[202555],
#         [375497]])
# self.order2nodes[order]: [227601, 397236]
# x: tensor([[227601],
#         [397236]])
# self.order2nodes[order]: [282639, 377045]
# x: tensor([[282639],
#         [377045]])
# self.order2nodes[order]: [228572, 399040]
# x: tensor([[228572],
#         [399040]])
# self.order2nodes[order]: [336917, 349445, 361478, 392433, 349675]
# x: tensor([[336917],
#         [349445],
#         [361478],
#         [392433],
#         [349675]])
# self.order2nodes[order]: [276387, 350857]
# x: tensor([[276387],
#         [350857]])
# self.order2nodes[order]: [179181, 352283, 353387, 392330]
# x: tensor([[179181],
#         [352283],
#         [353387],
#         [392330]])
# self.order2nodes[order]: [24075, 369149, 391580, 353532]
# x: tensor([[ 24075],
#         [369149],
#         [391580],
#         [353532]])
# self.order2nodes[order]: [292933, 353616]
# x: tensor([[292933],
#         [353616]])
# self.order2nodes[order]: [340960, 389315, 382172, 379643, 359222]
# x: tensor([[340960],
#         [389315],
#         [382172],
#         [379643],
#         [359222]])
# self.order2nodes[order]: [246641, 357208, 373632, 343753, 355530, 394259]
# x: tensor([[246641],
#         [357208],
#         [373632],
#         [343753],
#         [355530],
#         [394259]])
# self.order2nodes[order]: [68762, 350685, 363560, 375869]
# x: tensor([[ 68762],
#         [350685],
#         [363560],
#         [375869]])
# self.order2nodes[order]: [321746, 396100]
# x: tensor([[321746],
#         [396100]])
# self.order2nodes[order]: [23343, 359409, 352690, 370444, 398405]
# x: tensor([[ 23343],
#         [359409],
#         [352690],
#         [370444],
#         [398405]])
# self.order2nodes[order]: [61441, 394415, 363934]
# x: tensor([[ 61441],
#         [394415],
#         [363934]])
# self.order2nodes[order]: [167179, 398123, 389177, 350298, 396470, 387188, 348156, 383409, 383605]
# x: tensor([[167179],
#         [398123],
#         [389177],
#         [350298],
#         [396470],
#         [387188],
#         [348156],
#         [383409],
#         [383605]])
# self.order2nodes[order]: [222241, 344569, 363838]
# x: tensor([[222241],
#         [344569],
#         [363838]])
# self.order2nodes[order]: [254753, 370399]
# x: tensor([[254753],
#         [370399]])
# self.order2nodes[order]: [198864, 357368, 391323, 369499, 384811, 348920, 357544, 371091, 357844, 356254, 376562, 381357, 376090]
# x: tensor([[198864],
#         [357368],
#         [391323],
#         [369499],
#         [384811],
#         [348920],
#         [357544],
#         [371091],
#         [357844],
#         [356254],
#         [376562],
#         [381357],
#         [376090]])
# self.order2nodes[order]: [107698, 395660, 368053, 398936]
# x: tensor([[107698],
#         [395660],
#         [368053],
#         [398936]])
# self.order2nodes[order]: [164906, 391002, 348703, 376090, 383427, 360266, 358690, 378543, 348937, 352467]
# x: tensor([[164906],
#         [391002],
#         [348703],
#         [376090],
#         [383427],
#         [360266],
#         [358690],
#         [378543],
#         [348937],
#         [352467]])
# self.order2nodes[order]: [267099, 397836]
# x: tensor([[267099],
#         [397836]])
# self.order2nodes[order]: [330001, 350561]
# x: tensor([[330001],
#         [350561]])
# self.order2nodes[order]: [330775, 370911, 345295]
# x: tensor([[330775],
#         [370911],
#         [345295]])
# self.order2nodes[order]: [199891, 384614]
# x: tensor([[199891],
#         [384614]])
# self.order2nodes[order]: [20203, 379253]
# x: tensor([[ 20203],
#         [379253]])
# self.order2nodes[order]: [339962, 357846, 387486, 379253]
# x: tensor([[339962],
#         [357846],
#         [387486],
#         [379253]])
# self.order2nodes[order]: [330139, 344865]
# x: tensor([[330139],
#         [344865]])
# self.order2nodes[order]: [338208, 372155, 376594, 363621]
# x: tensor([[338208],
#         [372155],
#         [376594],
#         [363621]])
# self.order2nodes[order]: [289957, 372725, 399452]
# x: tensor([[289957],
#         [372725],
#         [399452]])
# self.order2nodes[order]: [221865, 367655, 379872]
# x: tensor([[221865],
#         [367655],
#         [379872]])
# self.order2nodes[order]: [94811, 380512, 375869, 355377]
# x: tensor([[ 94811],
#         [380512],
#         [375869],
#         [355377]])
# self.order2nodes[order]: [282404, 345825, 359499, 365369, 396674, 384641]
# x: tensor([[282404],
#         [345825],
#         [359499],
#         [365369],
#         [396674],
#         [384641]])
# self.order2nodes[order]: [140146, 388480, 363425]
# x: tensor([[140146],
#         [388480],
#         [363425]])
# self.order2nodes[order]: [59038, 355171, 353517, 387840, 379054, 352951, 344247, 364415, 389644]
# x: tensor([[ 59038],
#         [355171],
#         [353517],
#         [387840],
#         [379054],
#         [352951],
#         [344247],
#         [364415],
#         [389644]])
# self.order2nodes[order]: [7023, 361751, 355007]
# x: tensor([[  7023],
#         [361751],
#         [355007]])
# self.order2nodes[order]: [277740, 385785, 376881, 344185, 373310]
# x: tensor([[277740],
#         [385785],
#         [376881],
#         [344185],
#         [373310]])
# self.order2nodes[order]: [245292, 352673]
# x: tensor([[245292],
#         [352673]])
# ...
#         [346260],
#         [347039]])
# self.order2nodes[order]: [266518, 368114, 371309, 376880, 362627, 358151, 373069, 363411]
# x: tensor([[266518],
#         [368114],
#         [371309],
#         [376880],
#         [362627],
#         [358151],
#         [373069],
#         [363411]])
# self.order2nodes[order]: [152389, 350078, 381354, 360880, 350718]
# x: tensor([[152389],
#         [350078],
#         [381354],
#         [360880],
#         [350718]])
# self.order2nodes[order]: [309817, 383741, 368102, 359174]
# x: tensor([[309817],
#         [383741],
#         [368102],
#         [359174]])
# self.order2nodes[order]: [312447, 387726, 352526]
# x: tensor([[312447],
#         [387726],
#         [352526]])
# self.order2nodes[order]: [123651, 355357, 356254, 385325, 378869]
# x: tensor([[123651],
#         [355357],
#         [356254],
#         [385325],
#         [378869]])
# self.order2nodes[order]: [284248, 387441, 397819, 384887, 357416]
# x: tensor([[284248],
#         [387441],
#         [397819],
#         [384887],
#         [357416]])
# self.order2nodes[order]: [147429, 394812]
# x: tensor([[147429],
#         [394812]])
# self.order2nodes[order]: [152253, 355993, 387101, 398895, 369609, 374147, 359641, 381440, 378186, 387993, 374670, 343188, 342117]
# x: tensor([[152253],
#         [355993],
#         [387101],
#         [398895],
#         [369609],
#         [374147],
#         [359641],
#         [381440],
#         [378186],
#         [387993],
#         [374670],
#         [343188],
#         [342117]])
# self.order2nodes[order]: [181703, 378517, 356891]
# x: tensor([[181703],
#         [378517],
#         [356891]])
# self.order2nodes[order]: [229445, 369221, 348529, 371562]
# x: tensor([[229445],
#         [369221],
#         [348529],
#         [371562]])
# self.order2nodes[order]: [297680, 374051, 369294, 373870, 399502, 400389, 382781]
# x: tensor([[297680],
#         [374051],
#         [369294],
#         [373870],
#         [399502],
#         [400389],
#         [382781]])
# self.order2nodes[order]: [244235, 386118]
# x: tensor([[244235],
#         [386118]])
# self.order2nodes[order]: [116578, 381191]
# x: tensor([[116578],
#         [381191]])
# self.order2nodes[order]: [60449, 379027, 360181, 357453, 342792, 397847, 399952, 370086, 396407, 368890, 393110, 367756, 386772, 365322]
# x: tensor([[ 60449],
#         [379027],
#         [360181],
#         [357453],
#         [342792],
#         [397847],
#         [399952],
#         [370086],
#         [396407],
#         [368890],
#         [393110],
#         [367756],
#         [386772],
#         [365322]])
# self.order2nodes[order]: [2680, 359325, 385182, 371556]
# x: tensor([[  2680],
#         [359325],
#         [385182],
#         [371556]])
# self.order2nodes[order]: [7207, 390749]
# x: tensor([[  7207],
#         [390749]])
# self.order2nodes[order]: [281831, 348813]
# x: tensor([[281831],
#         [348813]])
# self.order2nodes[order]: [161661, 351061, 364950, 359173, 357145, 362282]
# x: tensor([[161661],
#         [351061],
#         [364950],
#         [359173],
#         [357145],
#         [362282]])
# self.order2nodes[order]: [159176, 375835, 393613, 348596, 373656, 347766, 350078]
# x: tensor([[159176],
#         [375835],
#         [393613],
#         [348596],
#         [373656],
#         [347766],
#         [350078]])
# self.order2nodes[order]: [32484, 388931]
# x: tensor([[ 32484],
#         [388931]])
# self.order2nodes[order]: [339102, 357924]
# x: tensor([[339102],
#         [357924]])
# self.order2nodes[order]: [321750, 367272, 370399, 381045]
# x: tensor([[321750],
#         [367272],
#         [370399],
#         [381045]])
# self.order2nodes[order]: [74269, 383355, 387346, 372312, 355788, 384440, 362879, 398656, 369610, 366428]
# x: tensor([[ 74269],
#         [383355],
#         [387346],
#         [372312],
#         [355788],
#         [384440],
#         [362879],
#         [398656],
#         [369610],
#         [366428]])
# self.order2nodes[order]: [42771, 365546, 367034]
# x: tensor([[ 42771],
#         [365546],
#         [367034]])
# self.order2nodes[order]: [6075, 370059, 374237, 381748]
# x: tensor([[  6075],
#         [370059],
#         [374237],
#         [381748]])
# self.order2nodes[order]: [115242, 383205, 381695]
# x: tensor([[115242],
#         [383205],
#         [381695]])
# self.order2nodes[order]: [115498, 363283]
# x: tensor([[115498],
#         [363283]])
# self.order2nodes[order]: [22042, 371543]
# x: tensor([[ 22042],
#         [371543]])
# self.order2nodes[order]: [31570, 378548, 356542, 393400, 351555, 386602]
# x: tensor([[ 31570],
#         [378548],
#         [356542],
#         [393400],
#         [351555],
#         [386602]])
# self.order2nodes[order]: [169395, 349186, 390433]
# x: tensor([[169395],
#         [349186],
#         [390433]])
# self.order2nodes[order]: [259725, 396541, 399990, 360648, 344308, 381513, 365001]
# x: tensor([[259725],
#         [396541],
#         [399990],
#         [360648],
#         [344308],
#         [381513],
#         [365001]])
# self.order2nodes[order]: [340587, 366384, 386913, 360036, 397876]
# x: tensor([[340587],
#         [366384],
#         [386913],
#         [360036],
#         [397876]])
# self.order2nodes[order]: [139846, 365904, 384779, 345295]
# x: tensor([[139846],
#         [365904],
#         [384779],
#         [345295]])
# self.order2nodes[order]: [1556, 355858, 374726]
# x: tensor([[  1556],
#         [355858],
#         [374726]])
# self.order2nodes[order]: [137575, 344881]
# x: tensor([[137575],
#         [344881]])
# self.order2nodes[order]: [65961, 389842, 363557]
# x: tensor([[ 65961],
#         [389842],
#         [363557]])
# self.order2nodes[order]: [170713, 373203, 373324, 359485, 355678]
# x: tensor([[170713],
#         [373203],
#         [373324],
#         [359485],
#         [355678]])
# self.order2nodes[order]: [252783, 347754, 390178, 362156, 363972, 376019, 399964, 372442]
# x: tensor([[252783],
#         [347754],
#         [390178],
#         [362156],
#         [363972],
#         [376019],
#         [399964],
#         [372442]])
# self.order2nodes[order]: [129287, 380589]
# x: tensor([[129287],
#         [380589]])
# self.order2nodes[order]: [82083, 396209, 342848, 379441, 387988, 366811]
# x: tensor([[ 82083],
#         [396209],
#         [342848],
#         [379441],
#         [387988],
#         [366811]])
# self.order2nodes[order]: [20852, 396634, 397721]
# x: tensor([[ 20852],
#         [396634],
#         [397721]])
# self.order2nodes[order]: [313964, 383545]
# x: tensor([[313964],
#         [383545]])
# self.order2nodes[order]: [14415, 391353]
# x: tensor([[ 14415],
#         [391353]])
# self.order2nodes[order]: [321822, 362220, 342117]
# x: tensor([[321822],
#         [362220],
#         [342117]])
# self.order2nodes[order]: [21087, 363722, 352920]
# x: tensor([[ 21087],
#         [363722],
#         [352920]])
# self.order2nodes[order]: [338808, 369110, 353599, 364120, 350479, 399971]
# x: tensor([[338808],
#         [369110],
#         [353599],
#         [364120],
#         [350479],
#         [399971]])
# self.order2nodes[order]: [42858, 393557, 370266, 375911, 362297]
# x: tensor([[ 42858],
#         [393557],
#         [370266],
#         [375911],
#         [362297]])
# self.order2nodes[order]: [329200, 356938, 368302]
# x: tensor([[329200],
#         [356938],
#         [368302]])
# self.order2nodes[order]: [286215, 376735, 359691, 367345]
# x: tensor([[286215],
#         [376735],
#         [359691],
#         [367345]])
# self.order2nodes[order]: [193206, 363428, 398232]
# x: tensor([[193206],
#         [363428],
#         [398232]])
# self.order2nodes[order]: [261351, 351770]
# x: tensor([[261351],
#         [351770]])
# self.order2nodes[order]: [128821, 355657, 390754]
# x: tensor([[128821],
#         [355657],
#         [390754]])
# self.order2nodes[order]: [315406, 354061, 397392]
# x: tensor([[315406],
#         [354061],
#         [397392]])
# self.order2nodes[order]: [147189, 353688, 358197, 387439, 385482]
# x: tensor([[147189],
#         [353688],
#         [358197],
#         [387439],
#         [385482]])
# self.order2nodes[order]: [196322, 393613]
# x: tensor([[196322],
#         [393613]])
# self.order2nodes[order]: [187312, 399962]
# x: tensor([[187312],
#         [399962]])
# self.order2nodes[order]: [146390, 357895, 355558, 394002]
# x: tensor([[146390],
#         [357895],
#         [355558],
#         [394002]])
# self.order2nodes[order]: [252705, 361356, 391532, 358338, 393584, 347799]
# x: tensor([[252705],
#         [361356],
#         [391532],
#         [358338],
#         [393584],
#         [347799]])
# self.order2nodes[order]: [127772, 384343, 342896, 380586, 371809, 400322, 380974]
# x: tensor([[127772],
#         [384343],
#         [342896],
#         [380586],
#         [371809],
#         [400322],
#         [380974]])
# self.order2nodes[order]: [218541, 352216]
# x: tensor([[218541],
#         [352216]])
# self.order2nodes[order]: [183375, 383694, 353070]
# x: tensor([[183375],
#         [383694],
#         [353070]])
# self.order2nodes[order]: [185872, 355761, 366576, 364056, 394129]
# x: tensor([[185872],
#         [355761],
#         [366576],
#         [364056],
#         [394129]])
# self.order2nodes[order]: [303427, 364710, 345199, 394641, 375807, 383244, 385103]
# x: tensor([[303427],
#         [364710],
#         [345199],
#         [394641],
#         [375807],
#         [383244],
#         [385103]])
# self.order2nodes[order]: [76166, 390362, 342605]
# x: tensor([[ 76166],
#         [390362],
#         [342605]])
# self.order2nodes[order]: [337392, 365262, 395067]
# x: tensor([[337392],
#         [365262],
#         [395067]])
# self.order2nodes[order]: [307508, 360930]
# x: tensor([[307508],
#         [360930]])
# self.order2nodes[order]: [305897, 364305, 370418, 351023, 350260]
# x: tensor([[305897],
#         [364305],
#         [370418],
#         [351023],
#         [350260]])
# self.order2nodes[order]: [226210, 386829, 385799, 391371, 348578, 388628, 385572, 379496, 377033, 343685]
# x: tensor([[226210],
#         [386829],
#         [385799],
#         [391371],
#         [348578],
#         [388628],
#         [385572],
#         [379496],
#         [377033],
#         [343685]])
# self.order2nodes[order]: [106317, 393328, 347746]
# x: tensor([[106317],
#         [393328],
#         [347746]])
# self.order2nodes[order]: [195128, 363175, 392986, 394347]
# x: tensor([[195128],
#         [363175],
#         [392986],
#         [394347]])
# self.order2nodes[order]: [28953, 355993, 399425]
# x: tensor([[ 28953],
#         [355993],
#         [399425]])
# self.order2nodes[order]: [294950, 395078, 370316]
# x: tensor([[294950],
#         [395078],
#         [370316]])
# self.order2nodes[order]: [272672, 342979, 394420, 347225]
# x: tensor([[272672],
#         [342979],
#         [394420],
#         [347225]])
# self.order2nodes[order]: [144763, 363552, 396043, 353826, 349002, 375700]
# x: tensor([[144763],
#         [363552],
#         [396043],
#         [353826],
#         [349002],
#         [375700]])
# self.order2nodes[order]: [183140, 361255, 348361, 342117, 372569]
# x: tensor([[183140],
#         [361255],
#         [348361],
#         [342117],
#         [372569]])
# self.order2nodes[order]: [74335, 396293, 374449, 388049, 345963, 397372, 370828, 346163, 360350]
# x: tensor([[ 74335],
#         [396293],
#         [374449],
#         [388049],
#         [345963],
#         [397372],
#         [370828],
#         [346163],
#         [360350]])
# self.order2nodes[order]: [76581, 391720, 370266]
# x: tensor([[ 76581],
#         [391720],
#         [370266]])
# self.order2nodes[order]: [120518, 387188, 381468]
# x: tensor([[120518],
#         [387188],
#         [381468]])
# self.order2nodes[order]: [219477, 358197, 378402, 349119]
# x: tensor([[219477],
#         [358197],
#         [378402],
#         [349119]])
# self.order2nodes[order]: [111099, 385753, 382690]
# x: tensor([[111099],
#         [385753],
#         [382690]])
# self.order2nodes[order]: [338145, 383019]
# x: tensor([[338145],
#         [383019]])
# self.order2nodes[order]: [292685, 381660]
# x: tensor([[292685],
#         [381660]])
# self.order2nodes[order]: [79292, 393646, 349227]
# x: tensor([[ 79292],
#         [393646],
#         [349227]])
# self.order2nodes[order]: [151312, 390999, 342427, 347030]
# x: tensor([[151312],
#         [390999],
#         [342427],
#         [347030]])
# self.order2nodes[order]: [132621, 366090]
# x: tensor([[132621],
#         [366090]])
# self.order2nodes[order]: [110412, 349373, 399865, 345859]
# x: tensor([[110412],
#         [349373],
#         [399865],
#         [345859]])
# self.order2nodes[order]: [110668, 350688, 357544, 370605, 398563, 395348, 349639, 381315, 371543, 397430]
# x: tensor([[110668],
#         [350688],
#         [357544],
#         [370605],
#         [398563],
#         [395348],
#         [349639],
#         [381315],
#         [371543],
#         [397430]])
# self.order2nodes[order]: [128821, 380476]
# x: tensor([[128821],
#         [380476]])
# self.order2nodes[order]: [126794, 381820]
# x: tensor([[126794],
#         [381820]])
# self.order2nodes[order]: [60233, 360410]
# x: tensor([[ 60233],
#         [360410]])
# self.order2nodes[order]: [229722, 360223]
# x: tensor([[229722],
#         [360223]])
# self.order2nodes[order]: [335042, 358151, 382199, 369037]
# x: tensor([[335042],
#         [358151],
#         [382199],
#         [369037]])
# self.order2nodes[order]: [107600, 398554]
# x: tensor([[107600],
#         [398554]])
# self.order2nodes[order]: [50676, 383280, 343011, 395444, 365270, 394002, 358968]
# x: tensor([[ 50676],
#         [383280],
#         [343011],
#         [395444],
#         [365270],
#         [394002],
#         [358968]])
# self.order2nodes[order]: [74602, 380869]
# x: tensor([[ 74602],
#         [380869]])
# self.order2nodes[order]: [43091, 354957, 376915, 371302, 348500, 371742]
# x: tensor([[ 43091],
#         [354957],
#         [376915],
#         [371302],
#         [348500],
#         [371742]])
# self.order2nodes[order]: [222932, 394420, 343995]
# x: tensor([[222932],
#         [394420],
#         [343995]])
# self.order2nodes[order]: [123619, 355699, 393492, 375776, 371783]
# x: tensor([[123619],
#         [355699],
#         [393492],
#         [375776],
#         [371783]])
# self.order2nodes[order]: [312437, 352514, 356938, 398207, 355513, 359547, 342417]
# x: tensor([[312437],
#         [352514],
#         [356938],
#         [398207],
#         [355513],
#         [359547],
#         [342417]])
# self.order2nodes[order]: [150854, 358457, 359667, 349133]
# x: tensor([[150854],
#         [358457],
#         [359667],
#         [349133]])
# self.order2nodes[order]: [211879, 365010, 342991]
# x: tensor([[211879],
#         [365010],
#         [342991]])
# self.order2nodes[order]: [278630, 382979]
# x: tensor([[278630],
#         [382979]])
# self.order2nodes[order]: [262650, 372862, 367653]
# x: tensor([[262650],
#         [372862],
#         [367653]])
# self.order2nodes[order]: [116218, 381005, 386150, 374448, 353011, 367209, 378793, 367064, 368073]
# x: tensor([[116218],
#         [381005],
#         [386150],
#         [374448],
#         [353011],
#         [367209],
#         [378793],
#         [367064],
#         [368073]])
# self.order2nodes[order]: [256160, 347172, 394129]
# x: tensor([[256160],
#         [347172],
#         [394129]])
# self.order2nodes[order]: [135990, 378538, 396566, 389062]
# x: tensor([[135990],
#         [378538],
#         [396566],
#         [389062]])
# self.order2nodes[order]: [98676, 380185]
# x: tensor([[ 98676],
#         [380185]])
# self.order2nodes[order]: [204430, 391092, 370177]
# x: tensor([[204430],
#         [391092],
#         [370177]])
# self.order2nodes[order]: [293664, 396314, 356588]
# x: tensor([[293664],
#         [396314],
#         [356588]])
# self.order2nodes[order]: [180455, 358409]
# x: tensor([[180455],
#         [358409]])
# self.order2nodes[order]: [107424, 362187, 382883, 354832, 388360, 362090, 380707, 398115, 369235, 392976]
# x: tensor([[107424],
#         [362187],
#         [382883],
#         [354832],
#         [388360],
#         [362090],
#         [380707],
#         [398115],
#         [369235],
#         [392976]])
# self.order2nodes[order]: [187110, 384391]
# x: tensor([[187110],
#         [384391]])
# self.order2nodes[order]: [306002, 399098, 345042, 368599, 356307]
# x: tensor([[306002],
#         [399098],
#         [345042],
#         [368599],
#         [356307]])
# self.order2nodes[order]: [92255, 376680]
# x: tensor([[ 92255],
#         [376680]])
# self.order2nodes[order]: [315299, 367267]
# x: tensor([[315299],
#         [367267]])
# self.order2nodes[order]: [226117, 395768, 350182]
# x: tensor([[226117],
#         [395768],
#         [350182]])
# self.order2nodes[order]: [292209, 385591, 383244]
# x: tensor([[292209],
#         [385591],
#         [383244]])
# self.order2nodes[order]: [21840, 367652, 347589]
# x:

# %%
print(train_ds[0])
# Out:
# Data(x=[3, 1], edge_index=[2, 6], y=0)

# %%
print(train_ds[0].x)
# Out:
# tensor([[192219],
#         [396693],
#         [399166]])

# %%
# before print(train_ds[0])
# Out:
# Data(x=[3, 3], edge_index=[2, 6], y=0)

# %%
train_dl = DataLoader(train_ds, batch_size=16)

# %%
iterator = iter(train_dl)

data = next(iterator)

# %%
print(data)
# Out:
# DataBatch(x=[56, 3], edge_index=[2, 182], y=[16], batch=[56], ptr=[17])

# %%
print(data.x)
# Out:
# tensor([[-0.0456,  0.1405,  0.2278],
#         [-0.1271,  0.1256,  0.2542],
#         [ 0.2904,  0.2979,  0.1018],
#         [ 1.0848, -0.2395, -0.3550],
#         [ 0.3586,  0.3384,  0.2293],
#         [ 0.1212,  0.1525, -0.2799],
#         [ 0.1283,  0.1448, -0.2521],
#         [ 0.2314,  0.1740,  0.0636],
#         [ 0.2751,  0.1501,  0.1873],
#         [ 0.4930,  0.3891,  0.4467],
#         [ 0.3279,  0.1562,  0.1717],
#         [ 0.7222,  0.3768,  0.0729],
#         [ 0.7691,  0.2457,  0.3380],
#         [ 0.0000,  0.0000,  0.0000],
#         [ 0.1060,  0.0815,  0.1212],
#         [ 2.8266,  0.8957,  2.2240],
#         [ 1.4502,  0.3533,  1.4634],
#         [ 0.1340,  0.1835,  0.3068],
#         [ 0.0000,  0.0000,  0.0000],
#         [ 1.9344,  0.6038,  1.5723],
#         [ 0.0836,  0.1247,  0.1380],
#         [-0.1206,  0.0769,  0.1455],
#         [ 0.0330,  0.1927,  1.0494],
#         [-0.0576, -0.0126,  0.0916],
#         [-0.3438, -0.2391,  0.1159],
#         [ 0.0303,  0.1769,  0.9634],
#         [ 0.0542,  0.0602,  0.2567],
#         [ 0.2922,  0.2417,  0.0520],
#         [ 0.2331,  0.2211,  0.2819],
#         [ 0.1080,  0.0489,  0.2378],
#         [ 0.0823,  0.1640,  0.0872],
#         [ 0.0683,  0.0509,  0.1001],
#         [ 0.2072,  0.1502,  0.2532],
#         [ 0.1402,  0.1274,  0.1463],
#         [ 0.6010,  0.1689,  0.0443],
#         [ 0.0891,  0.0902,  0.1030],
#         [ 0.3542,  0.2222, -0.1251],
#         [ 0.0000,  0.0000,  0.0000],
#         [ 0.4325,  0.2293, -0.0666],
#         [ 0.2139,  0.1314,  0.0293],
#         [ 0.2137,  0.1890,  0.1689],
#         [ 0.1128,  0.1712,  0.2010],
#         [ 0.1779,  0.2166,  0.0775],
#         [ 0.1845,  0.1342,  0.0544],
#         [ 0.0000,  0.0000,  0.0000],
#         [-0.5011, -0.2534, -0.6092],
#         [ 0.1966,  0.2389,  0.3255],
#         [ 0.2888,  0.1407,  0.0540],
#         [ 0.0037, -0.1534,  0.1191],
#         [ 0.0579, -0.1173, -0.1921],
#         [-0.0275, -0.0134, -0.1279],
#         [ 0.4163,  0.2104,  0.1522],
#         [ 0.4089,  0.0454, -0.2282],
#         [ 0.8334,  0.2351,  0.4241],
#         [ 0.1211,  0.1606,  0.1219],
#         [ 0.3213,  0.2659,  0.3038]], device='cuda:0', grad_fn=<CatBackward0>)

# %%
from torch_geometric.nn.pool import global_mean_pool

class SecondGAT(torch.nn.Module):
    def __init__(self, in_channels, out_channels, heads=4, dropout=0.1):
        super(SecondGAT, self).__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.gat1 = GATConv(in_channels, 8, heads=heads, dropout=dropout)
        self.gat3 = GATConv(8*heads, out_channels, heads=1, dropout=dropout)
        self.fc1 = nn.Linear(out_channels, 10)
        self.fc2 = nn.Linear(10, 3)
    
    def forward(self, x, edge_index, batch_idx):
        
        x = F.dropout(x, p=0.1)
        x = F.elu(self.gat1(x, edge_index))
        #x = F.elu(self.gat_test(x, edge_index))
        x = F.dropout(x, p=0.1)
        #x = F.elu(self.gat2(x, edge_index))
        #x = F.dropout(x, p=0.1, training=self.training)
        x = F.elu(self.gat3(x, edge_index))
        x = global_mean_pool(x, batch_idx)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, p=0.1)
        x = self.fc2(x)
        
        # pooling
        
        return x

# %%
def train(saved_data, dataloader, in_channels=10, out_channels=10, heads=8, epochs=10, batch_size=64, lr=1e-3, step_size=2, save_period=5000, save_path='saved_models/'):
    
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print('device:', device)
    
    
    # 모델 생성
    first_model = FirstGAT(10, in_channels, heads=4).to(device)
    second_model = SecondGAT(in_channels, out_channels, heads=heads).to(device)
    

    # data
    saved_data = saved_data.to(device)
    prod_features, edge_index, order2labels, order2nodes = saved_data.prod_features, saved_data.edge_index, saved_data.order2labels, saved_data.order2nodes 


    # 손실 함수 및 옵티마이저 정의
    criterion = torch.nn.CrossEntropyLoss()
    #optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-3)
    optimizer = torch.optim.Adam(list(first_model.parameters()) +  list(second_model.parameters()), lr=lr)
    scheduler = StepLR(optimizer, step_size=step_size, gamma=0.5) # 학습률 스케줄러 추가


    min_loss = 10
    #모델 학습
    first_model.train()
    second_model.train()
    for epoch in range(epochs):
        for i, data in enumerate(dataloader):
            node_features = first_model(prod_features, edge_index)
            
            x, edge_index, y, batch_idx = data.x, data.edge_index, data.y, data.batch
            edge_index = edge_index.to(device)
            y = torch.tensor(y).to(device)
            #print('edge device:',  edge_index.device)

            # edge_index=[2, 182], y=[16], batch=[56]
            
            out = second_model(x, edge_index, batch_idx)
            optimizer.zero_grad()
            loss = criterion(out, y)
            loss.backward()
            optimizer.step()
            
            if i % 20 == 0:
                print(f'Epoch {epoch}, batch_idx {i}/{len(dataloader)+1} Loss: {loss.item()}')
                
            if loss < min_loss:
                min_loss = loss
                min_epoch = epoch
                save_model(path=save_path, first_model=first_model, second_model=second_model, opt=optimizer, scheduler=scheduler, loss=loss, epoch=epoch)
            
        scheduler.step() # 학습률 스케쥴러 업데이트
    
    print(f'min_loss: {min_loss:.3f}, epoch: {min_epoch}')

# 모델 평가 
def evaluate(model, prod_features, orders, order2nodes, edge_index, targets):
    model.eval()
    pred = model(prod_features, orders, order2nodes, edge_index).argmax(dim=1) #prod_features, orders, order2nodes, edge_index
    #print('pred:', pred)
    accuracy = (pred == targets).sum().item() / targets.size(0)
    print(f'Accuracy: {accuracy}')

# %%
train(first_model=model1, dataloader=train_dl, in_channels=10, out_channels=10, heads=8, epochs= 10, batch_size=64, lr=1e-2, step_size=2, save_period=10, save_path='/home/myeongjin/data-mining/saved_models/second_step_test')
# Out:
# device: cuda
# Epoch 0, batch_idx 0/37153 Loss: 1.135193109512329
# Epoch 0, batch_idx 20/37153 Loss: 1.156882405281067
# Epoch 0, batch_idx 40/37153 Loss: 1.114025592803955
# Epoch 0, batch_idx 60/37153 Loss: 1.1904520988464355
# Epoch 0, batch_idx 80/37153 Loss: 1.152680516242981
# Epoch 0, batch_idx 100/37153 Loss: 1.1646422147750854
# Epoch 0, batch_idx 120/37153 Loss: 1.0752894878387451
# Epoch 0, batch_idx 140/37153 Loss: 1.120540976524353
# Epoch 0, batch_idx 160/37153 Loss: 1.1264289617538452
# Epoch 0, batch_idx 180/37153 Loss: 1.0834499597549438
# Epoch 0, batch_idx 200/37153 Loss: 1.0945990085601807
# Epoch 0, batch_idx 220/37153 Loss: 1.030975580215454
# Epoch 0, batch_idx 240/37153 Loss: 1.063046932220459
# Epoch 0, batch_idx 260/37153 Loss: 1.1156682968139648
# Epoch 0, batch_idx 280/37153 Loss: 1.1577715873718262
# Epoch 0, batch_idx 300/37153 Loss: 1.0089219808578491
# Epoch 0, batch_idx 320/37153 Loss: 1.0914503335952759
# Epoch 0, batch_idx 340/37153 Loss: 1.0673242807388306
# Epoch 0, batch_idx 360/37153 Loss: 0.9993501901626587
# Epoch 0, batch_idx 380/37153 Loss: 1.1372895240783691
# Epoch 0, batch_idx 400/37153 Loss: 1.0842725038528442
# Epoch 0, batch_idx 420/37153 Loss: 0.9774780869483948
# Epoch 0, batch_idx 440/37153 Loss: 1.067787528038025
# Epoch 0, batch_idx 460/37153 Loss: 1.0918666124343872
# Epoch 0, batch_idx 480/37153 Loss: 1.0587918758392334
# Epoch 0, batch_idx 500/37153 Loss: 1.0935900211334229
# Epoch 0, batch_idx 520/37153 Loss: 1.1226752996444702
# Epoch 0, batch_idx 540/37153 Loss: 1.0936636924743652
# Epoch 0, batch_idx 560/37153 Loss: 1.0212963819503784
# Epoch 0, batch_idx 580/37153 Loss: 1.0647881031036377
# Epoch 0, batch_idx 600/37153 Loss: 1.0444540977478027
# Epoch 0, batch_idx 620/37153 Loss: 1.0787973403930664
# Epoch 0, batch_idx 640/37153 Loss: 1.0935841798782349
# Epoch 0, batch_idx 660/37153 Loss: 1.1070117950439453
# Epoch 0, batch_idx 680/37153 Loss: 1.0514377355575562
# Epoch 0, batch_idx 700/37153 Loss: 1.0785439014434814
# Epoch 0, batch_idx 720/37153 Loss: 1.0806822776794434
# Epoch 0, batch_idx 740/37153 Loss: 1.049453854560852
# Epoch 0, batch_idx 760/37153 Loss: 1.0916500091552734
# Epoch 0, batch_idx 780/37153 Loss: 1.100895881652832
# Epoch 0, batch_idx 800/37153 Loss: 1.1143240928649902
# Epoch 0, batch_idx 820/37153 Loss: 1.1530556678771973
# Epoch 0, batch_idx 840/37153 Loss: 1.0669320821762085
# Epoch 0, batch_idx 860/37153 Loss: 1.0634372234344482
# Epoch 0, batch_idx 880/37153 Loss: 1.0453368425369263
# Epoch 0, batch_idx 900/37153 Loss: 1.0705807209014893
# Epoch 0, batch_idx 920/37153 Loss: 1.075442910194397
# Epoch 0, batch_idx 940/37153 Loss: 1.107282280921936
# Epoch 0, batch_idx 960/37153 Loss: 1.0710402727127075
# Epoch 0, batch_idx 980/37153 Loss: 1.096751093864441
# Epoch 0, batch_idx 1000/37153 Loss: 1.1069148778915405
# Epoch 0, batch_idx 1020/37153 Loss: 1.0286855697631836
# Epoch 0, batch_idx 1040/37153 Loss: 1.1210352182388306
# Epoch 0, batch_idx 1060/37153 Loss: 1.0886876583099365
# Epoch 0, batch_idx 1080/37153 Loss: 1.085514783859253
# Epoch 0, batch_idx 1100/37153 Loss: 1.019650936126709
# Epoch 0, batch_idx 1120/37153 Loss: 0.980065107345581
# Epoch 0, batch_idx 1140/37153 Loss: 1.094178557395935
# Epoch 0, batch_idx 1160/37153 Loss: 1.096407175064087
# Epoch 0, batch_idx 1180/37153 Loss: 1.0409883260726929
# Epoch 0, batch_idx 1200/37153 Loss: 1.0724999904632568
# Epoch 0, batch_idx 1220/37153 Loss: 1.0005202293395996
# Epoch 0, batch_idx 1240/37153 Loss: 1.0269277095794678
# Epoch 0, batch_idx 1260/37153 Loss: 1.072867512702942
# Epoch 0, batch_idx 1280/37153 Loss: 1.0675204992294312
# Epoch 0, batch_idx 1300/37153 Loss: 0.9901022911071777
# Epoch 0, batch_idx 1320/37153 Loss: 1.145182490348816
# Epoch 0, batch_idx 1340/37153 Loss: 1.0852656364440918
# Epoch 0, batch_idx 1360/37153 Loss: 1.0444517135620117
# Epoch 0, batch_idx 1380/37153 Loss: 0.9704607725143433
# Epoch 0, batch_idx 1400/37153 Loss: 1.0331761837005615
# Epoch 0, batch_idx 1420/37153 Loss: 1.1059439182281494
# Epoch 0, batch_idx 1440/37153 Loss: 1.2257524728775024
# Epoch 0, batch_idx 1460/37153 Loss: 1.0002809762954712
# Epoch 0, batch_idx 1480/37153 Loss: 1.0295244455337524
# Epoch 0, batch_idx 1500/37153 Loss: 1.1869151592254639
# Epoch 0, batch_idx 1520/37153 Loss: 1.078631043434143
# Epoch 0, batch_idx 1540/37153 Loss: 1.016390323638916
# Epoch 0, batch_idx 1560/37153 Loss: 0.9987657070159912
# Epoch 0, batch_idx 1580/37153 Loss: 1.2124648094177246
# Epoch 0, batch_idx 1600/37153 Loss: 1.1198561191558838
# Epoch 0, batch_idx 1620/37153 Loss: 1.044448971748352
# Epoch 0, batch_idx 1640/37153 Loss: 1.0216960906982422
# Epoch 0, batch_idx 1660/37153 Loss: 1.1009365320205688
# Epoch 0, batch_idx 1680/37153 Loss: 1.1093336343765259
# Epoch 0, batch_idx 1700/37153 Loss: 1.0377646684646606
# Epoch 0, batch_idx 1720/37153 Loss: 1.0665842294692993
# Epoch 0, batch_idx 1740/37153 Loss: 1.1150479316711426
# Epoch 0, batch_idx 1760/37153 Loss: 1.0394477844238281
# Epoch 0, batch_idx 1780/37153 Loss: 1.1464133262634277
# Epoch 0, batch_idx 1800/37153 Loss: 1.0165226459503174
# Epoch 0, batch_idx 1820/37153 Loss: 0.9580104351043701
# Epoch 0, batch_idx 1840/37153 Loss: 1.0573152303695679
# Epoch 0, batch_idx 1860/37153 Loss: 1.0874736309051514
# Epoch 0, batch_idx 1880/37153 Loss: 1.1272037029266357
# Epoch 0, batch_idx 1900/37153 Loss: 1.270822286605835
# Epoch 0, batch_idx 1920/37153 Loss: 1.0893361568450928
# Epoch 0, batch_idx 1940/37153 Loss: 1.1686276197433472
# Epoch 0, batch_idx 1960/37153 Loss: 1.0622646808624268
# Epoch 0, batch_idx 1980/37153 Loss: 1.0938626527786255
# Epoch 0, batch_idx 2000/37153 Loss: 1.0091381072998047
# Epoch 0, batch_idx 2020/37153 Loss: 1.176523208618164
# Epoch 0, batch_idx 2040/37153 Loss: 1.2098126411437988
# Epoch 0, batch_idx 2060/37153 Loss: 1.0932836532592773
# Epoch 0, batch_idx 2080/37153 Loss: 1.0508085489273071
# Epoch 0, batch_idx 2100/37153 Loss: 1.0097726583480835
# Epoch 0, batch_idx 2120/37153 Loss: 0.9836276769638062
# Epoch 0, batch_idx 2140/37153 Loss: 1.0621052980422974
# Epoch 0, batch_idx 2160/37153 Loss: 1.1110531091690063
# Epoch 0, batch_idx 2180/37153 Loss: 1.0450329780578613
# Epoch 0, batch_idx 2200/37153 Loss: 1.1439441442489624
# Epoch 0, batch_idx 2220/37153 Loss: 1.0582488775253296
# Epoch 0, batch_idx 2240/37153 Loss: 1.0734010934829712
# Epoch 0, batch_idx 2260/37153 Loss: 1.0735844373703003
# Epoch 0, batch_idx 2280/37153 Loss: 1.0789825916290283
# Epoch 0, batch_idx 2300/37153 Loss: 1.2509207725524902
# Epoch 0, batch_idx 2320/37153 Loss: 1.102161169052124
# Epoch 0, batch_idx 2340/37153 Loss: 1.1309735774993896
# Epoch 0, batch_idx 2360/37153 Loss: 1.0446470975875854
# Epoch 0, batch_idx 2380/37153 Loss: 1.1437889337539673
# Epoch 0, batch_idx 2400/37153 Loss: 1.011177897453308
# Epoch 0, batch_idx 2420/37153 Loss: 1.0977396965026855
# Epoch 0, batch_idx 2440/37153 Loss: 1.0742394924163818
# Epoch 0, batch_idx 2460/37153 Loss: 0.9711335897445679
# Epoch 0, batch_idx 2480/37153 Loss: 1.184895634651184
# Epoch 0, batch_idx 2500/37153 Loss: 1.0935750007629395
# Epoch 0, batch_idx 2520/37153 Loss: 1.0549269914627075
# Epoch 0, batch_idx 2540/37153 Loss: 1.0470296144485474
# Epoch 0, batch_idx 2560/37153 Loss: 1.0391463041305542
# Epoch 0, batch_idx 2580/37153 Loss: 1.0353260040283203
# Epoch 0, batch_idx 2600/37153 Loss: 1.1260539293289185
# Epoch 0, batch_idx 2620/37153 Loss: 1.1396236419677734
# Epoch 0, batch_idx 2640/37153 Loss: 1.0336962938308716
# Epoch 0, batch_idx 2660/37153 Loss: 1.0840212106704712
# Epoch 0, batch_idx 2680/37153 Loss: 1.0930514335632324
# Epoch 0, batch_idx 2700/37153 Loss: 1.0319181680679321
# Epoch 0, batch_idx 2720/37153 Loss: 1.0298700332641602
# Epoch 0, batch_idx 2740/37153 Loss: 1.1242729425430298
# Epoch 0, batch_idx 2760/37153 Loss: 1.1199291944503784
# Epoch 0, batch_idx 2780/37153 Loss: 1.0655152797698975
# Epoch 0, batch_idx 2800/37153 Loss: 1.0658584833145142
# Epoch 0, batch_idx 2820/37153 Loss: 1.0284391641616821
# Epoch 0, batch_idx 2840/37153 Loss: 1.0440731048583984
# Epoch 0, batch_idx 2860/37153 Loss: 0.9572346806526184
# Epoch 0, batch_idx 2880/37153 Loss: 0.9983768463134766
# Epoch 0, batch_idx 2900/37153 Loss: 1.0970768928527832
# Epoch 0, batch_idx 2920/37153 Loss: 1.2094186544418335
# Epoch 0, batch_idx 2940/37153 Loss: 1.1655361652374268
# Epoch 0, batch_idx 2960/37153 Loss: 1.0288889408111572
# Epoch 0, batch_idx 2980/37153 Loss: 1.019404411315918
# Epoch 0, batch_idx 3000/37153 Loss: 1.0167821645736694
# Epoch 0, batch_idx 3020/37153 Loss: 1.070162296295166
# Epoch 0, batch_idx 3040/37153 Loss: 1.0482476949691772
# Epoch 0, batch_idx 3060/37153 Loss: 1.0409488677978516
# Epoch 0, batch_idx 3080/37153 Loss: 1.0632712841033936
# Epoch 0, batch_idx 3100/37153 Loss: 1.0977543592453003
# Epoch 0, batch_idx 3120/37153 Loss: 1.1065093278884888
# Epoch 0, batch_idx 3140/37153 Loss: 1.189581274986267
# Epoch 0, batch_idx 3160/37153 Loss: 0.9605877995491028
# Epoch 0, batch_idx 3180/37153 Loss: 1.0951803922653198
# Epoch 0, batch_idx 3200/37153 Loss: 1.1757622957229614
# Epoch 0, batch_idx 3220/37153 Loss: 1.0650631189346313
# Epoch 0, batch_idx 3240/37153 Loss: 1.1094802618026733
# Epoch 0, batch_idx 3260/37153 Loss: 1.013142704963684
# Epoch 0, batch_idx 3280/37153 Loss: 1.049454689025879
# Epoch 0, batch_idx 3300/37153 Loss: 1.0988858938217163
# Epoch 0, batch_idx 3320/37153 Loss: 1.0085099935531616
# Epoch 0, batch_idx 3340/37153 Loss: 1.0154393911361694
# Epoch 0, batch_idx 3360/37153 Loss: 1.0713001489639282
# Epoch 0, batch_idx 3380/37153 Loss: 1.079423189163208
# Epoch 0, batch_idx 3400/37153 Loss: 0.9882031679153442
# Epoch 0, batch_idx 3420/37153 Loss: 0.9762068390846252
# Epoch 0, batch_idx 3440/37153 Loss: 1.1460940837860107
# Epoch 0, batch_idx 3460/37153 Loss: 1.0964927673339844
# Epoch 0, batch_idx 3480/37153 Loss: 0.9842405319213867
# Epoch 0, batch_idx 3500/37153 Loss: 1.0163626670837402
# Epoch 0, batch_idx 3520/37153 Loss: 1.0637303590774536
# Epoch 0, batch_idx 3540/37153 Loss: 1.1003963947296143
# Epoch 0, batch_idx 3560/37153 Loss: 1.0774524211883545
# Epoch 0, batch_idx 3580/37153 Loss: 1.037858486175537
# Epoch 0, batch_idx 3600/37153 Loss: 1.0969762802124023
# Epoch 0, batch_idx 3620/37153 Loss: 1.0826456546783447
# Epoch 0, batch_idx 3640/37153 Loss: 1.0135701894760132
# Epoch 0, batch_idx 3660/37153 Loss: 1.0998159646987915
# Epoch 0, batch_idx 3680/37153 Loss: 0.990889310836792
# Epoch 0, batch_idx 3700/37153 Loss: 1.095137119293213
# Epoch 0, batch_idx 3720/37153 Loss: 1.042344331741333
# Epoch 0, batch_idx 3740/37153 Loss: 1.083775520324707
# Epoch 0, batch_idx 3760/37153 Loss: 1.0387123823165894
# Epoch 0, batch_idx 3780/37153 Loss: 0.9542006254196167
# Epoch 0, batch_idx 3800/37153 Loss: 0.988335371017456
# Epoch 0, batch_idx 3820/37153 Loss: 0.9388653039932251
# Epoch 0, batch_idx 3840/37153 Loss: 1.0395721197128296
# Epoch 0, batch_idx 3860/37153 Loss: 1.035403847694397
# Epoch 0, batch_idx 3880/37153 Loss: 1.108319878578186
# Epoch 0, batch_idx 3900/37153 Loss: 1.067147135734558
# Epoch 0, batch_idx 3920/37153 Loss: 1.014316439628601
# Epoch 0, batch_idx 3940/37153 Loss: 1.016196846961975
# Epoch 0, batch_idx 3960/37153 Loss: 0.9126297831535339
# Epoch 0, batch_idx 3980/37153 Loss: 1.0589842796325684
# Epoch 0, batch_idx 4000/37153 Loss: 1.1682239770889282
# Epoch 0, batch_idx 4020/37153 Loss: 0.9024511575698853
# Epoch 0, batch_idx 4040/37153 Loss: 1.0358253717422485
# Epoch 0, batch_idx 4060/37153 Loss: 1.1588332653045654
# Epoch 0, batch_idx 4080/37153 Loss: 1.130246877670288
# Epoch 0, batch_idx 4100/37153 Loss: 1.066332221031189
# Epoch 0, batch_idx 4120/37153 Loss: 1.0813847780227661
# Epoch 0, batch_idx 4140/37153 Loss: 1.0701237916946411
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 train(first_model=model1, dataloader=train_dl, in_channels=3, out_channels=3, heads=8, epochs= 10, batch_size=64, lr=1e-3, step_size=2, save_period=10, save_path='/home/myeongjin/data-mining/saved_models/second_step_test')
#
# Cell In[61], line 30, in train(first_model, dataloader, in_channels, out_channels, heads, epochs, batch_size, lr, step_size, save_period, save_path)
#      25 y = torch.tensor(y).to(device)
#      26 #print('edge device:',  edge_index.device)
#      27
#      28 # edge_index=[2, 182], y=[16], batch=[56]
# ---> 30 out = second_model(x, edge_index, batch_idx)
#      31 optimizer.zero_grad()
#      32 loss = criterion(out, y)
#
# File ~/miniconda3/envs/datamining/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/datamining/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# Cell In[60], line 16, in SecondGAT.forward(self, x, edge_index, batch_idx)
#      13 def forward(self, x, edge_index, batch_idx):
#      15     x = F.dropout(x, p=0.1)
# ---> 16     x = F.elu(self.gat1(x, edge_index))
#      17     #x = F.elu(self.gat_test(x, edge_index))
#      18     x = F.dropout(x, p=0.1)
#
# File ~/miniconda3/envs/datamining/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/datamining/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/miniconda3/envs/datamining/lib/python3.12/site-packages/torch_geometric/nn/conv/gat_conv.py:341, in GATConv.forward(self, x, edge_index, edge_attr, size, return_attention_weights)
#     337 alpha = self.edge_updater(edge_index, alpha=alpha, edge_attr=edge_attr,
#     338                           size=size)
#     340 # propagate_type: (x: OptPairTensor, alpha: Tensor)
# --> 341 out = self.propagate(edge_index, x=x, alpha=alpha, size=size)
#     343 if self.concat:
#     344     out = out.view(-1, self.heads * self.out_channels)
#
# File /tmp/torch_geometric.nn.conv.gat_conv_GATConv_propagate_mrmx7100.py:167, in propagate(self, edge_index, x, alpha, size)
#     161 out = self.message(
#     162     x_j=kwargs.x_j,
#     163     alpha=kwargs.alpha,
#     164 )
#     166 # Begin Message Forward Hook ###########################################
# --> 167 if not torch.jit.is_scripting() and not is_compiling():
#     168     for hook in self._message_forward_hooks.values():
#     169         hook_kwargs = dict(
#     170             x_j=kwargs.x_j,
#     171             alpha=kwargs.alpha,
#     172         )
#
# File ~/miniconda3/envs/datamining/lib/python3.12/site-packages/torch/_jit_internal.py:1120, in is_scripting()
#    1116 for i in range(2, 7):
#    1117     globals()[f"BroadcastingList{i}"] = BroadcastingList1
# -> 1120 def is_scripting() -> bool:
#    1121     r"""
#    1122     Function that returns True when in compilation and False otherwise. This
#    1123     is useful especially with the @unused decorator to leave code in your
#    (...)
#    1137               return unsupported_linear_op(x)
#    1138     """
#    1139     return False
#
# KeyboardInterrupt:
